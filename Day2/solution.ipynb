# %%
import re

arr = []

with open("input.txt", "r") as file:
    for j, line in enumerate(file):
        elements = line.rstrip().split(":")
        #print(elements)
        game_results = elements[1].split(";")
        ##print(f'game_results: {game_results}, {len(game_results)}')
        dictionary = {}
        for i in range(0, len(game_results)):
            dictionary["game_id"] = j+1
            dictionary["game_res"]= game_results
        ##print(f'{dictionary}\n')
        arr.append(dictionary)

diz = []
desired_order = ['red', 'green', 'blue']
limit = {'red': 12, 'green': 13, 'blue': 14}

##print(arr[0]['game_res'])
##print('stop \n')

# Iterate over each element of arr. Each element of arr is a dictionary
for i in range(0,len(arr)):
    #print(arr[i]["game_id"])
    elements = arr[i]['game_res']
    #print(elements)

    new_arr = []

    for element in elements:
        result_dict = {}
        temp = element.lstrip().split(",")
        #print(f'temp: {temp}')
        for k in temp:
            key, value = k.lstrip().split(" ")
            result_dict[value] = int(key)
            #print(f'result_dict: {result_dict}')
        new_arr.append(result_dict)
            
        ##print(f'new arr: {new_arr}')
        
        switched_dict = {}
    
        for f in new_arr:
            switched_dict = {key: f.get(key, 0) for key in desired_order}
            if all(switched_dict[key] <= limit[key] for key in switched_dict):
                arr[i]["game_res"] = True
            else:
                arr[i]["game_res"] = False
                break
    ##print(f'ssss {switched_dict}, result: {arr[i]["game_res"]}')

        #diz.append(switched_dict)
        #print(f'res: {switched_dict}: {arr[i]["game_res"]}')

res = 0

for i in arr:
    ##print(i)
    if i['game_res'] == True:
        res += i['game_id']
print(res)
# Out:
# 2076

# %% [markdown]
# ## Part 2

# %%
import re

arr = []

with open("input.txt", "r") as file:
    for j, line in enumerate(file):
        elements = line.rstrip().split(":")
        #print(elements)
        game_results = elements[1].split(";")
        ##print(f'game_results: {game_results}, {len(game_results)}')
        dictionary = {}
        for i in range(0, len(game_results)):
            dictionary["game_id"] = j+1
            dictionary["game_res"]= game_results
        ##print(f'{dictionary}\n')
        arr.append(dictionary)

diz = []
desired_order = ['red', 'green', 'blue']
limit = {'red': 12, 'green': 13, 'blue': 14}

##print(arr[0]['game_res'])
##print('stop \n')
games = []
# Iterate over each element of arr. Each element of arr is a dictionary
for i in range(0,len(arr)):
    #print(arr[i]["game_id"])
    elements = arr[i]['game_res']
    #print(elements)
    new_arr = []
    for element in elements:
        result_dict = {}
        temp = element.lstrip().split(",")
        #print(f'temp: {temp}')
        for k in temp:
            key, value = k.lstrip().split(" ")
            result_dict[value] = int(key)
            #print(f'result_dict: {result_dict}')
        new_arr.append(result_dict)
    games.append(new_arr)

# %%
for i in games:
    print(i)
# Out:
# [{'green': 2, 'blue': 6, 'red': 7}, {'green': 12, 'blue': 6, 'red': 3}, {'red': 5, 'green': 18, 'blue': 4}]
# [{'green': 10, 'red': 4}, {'red': 2}, {'green': 12, 'red': 11, 'blue': 1}, {'blue': 1, 'red': 11, 'green': 5}, {'red': 10, 'green': 9, 'blue': 1}]
# [{'green': 3}, {'red': 15, 'blue': 7, 'green': 1}, {'red': 3, 'blue': 6, 'green': 1}, {'blue': 14, 'red': 13, 'green': 2}, {'green': 1, 'blue': 6, 'red': 6}, {'red': 16, 'blue': 13, 'green': 2}]
# [{'blue': 5}, {'blue': 8, 'red': 7}, {'blue': 9, 'red': 5, 'green': 4}, {'red': 4, 'green': 1}, {'red': 8, 'blue': 6}, {'blue': 2, 'red': 4, 'green': 3}]
# [{'blue': 3, 'red': 4, 'green': 10}, {'green': 13, 'blue': 8, 'red': 2}, {'red': 2, 'green': 4, 'blue': 6}, {'blue': 3, 'green': 5, 'red': 2}, {'red': 4, 'blue': 13, 'green': 8}, {'green': 9, 'red': 2}]
# [{'red': 3, 'blue': 2}, {'green': 6, 'blue': 13}, {'blue': 11, 'red': 1}, {'green': 4, 'red': 3, 'blue': 5}]
# [{'green': 14, 'red': 2, 'blue': 5}, {'blue': 4, 'green': 8}, {'red': 2, 'green': 2, 'blue': 9}]
# [{'green': 10, 'blue': 6}, {'green': 3, 'red': 4}, {'blue': 7, 'red': 7, 'green': 5}, {'red': 1, 'green': 11}, {'blue': 3, 'red': 2, 'green': 11}]
# [{'blue': 4, 'green': 1, 'red': 6}, {'red': 5, 'blue': 5}, {'blue': 1, 'red': 7}, {'red': 4, 'blue': 8}, {'red': 6}]
# [{'green': 3, 'blue': 7, 'red': 6}, {'red': 1, 'blue': 5}, {'red': 6}, {'red': 1, 'green': 5, 'blue': 6}, {'red': 5, 'blue': 2}, {'red': 6, 'blue': 4, 'green': 6}]
# [{'red': 8, 'blue': 6, 'green': 6}, {'blue': 5, 'red': 2, 'green': 5}, {'blue': 4, 'green': 5}, {'blue': 4, 'red': 3, 'green': 8}]
# [{'green': 5, 'red': 1, 'blue': 7}, {'red': 1, 'green': 10}, {'red': 6, 'green': 3, 'blue': 7}, {'red': 5, 'blue': 6, 'green': 7}, {'blue': 3, 'green': 4}, {'red': 1, 'blue': 3, 'green': 3}]
# [{'red': 11, 'blue': 9, 'green': 16}, {'red': 1, 'green': 3, 'blue': 3}, {'green': 14, 'red': 2, 'blue': 7}]
# [{'red': 4, 'blue': 8, 'green': 12}, {'blue': 7, 'red': 4, 'green': 2}, {'blue': 4, 'green': 7, 'red': 6}, {'red': 3, 'blue': 11, 'green': 12}]
# [{'red': 6}, {'red': 3, 'blue': 5}, {'red': 3, 'blue': 10, 'green': 1}, {'green': 2, 'red': 8, 'blue': 2}]
# [{'green': 2, 'red': 4, 'blue': 6}, {'green': 2, 'blue': 16, 'red': 2}, {'blue': 13, 'green': 7, 'red': 3}]
# [{'blue': 5}, {'blue': 1}, {'red': 2, 'green': 2, 'blue': 4}, {'blue': 6, 'green': 4, 'red': 2}]
# [{'red': 3}, {'green': 7, 'red': 11, 'blue': 6}, {'red': 6, 'blue': 3, 'green': 12}, {'red': 5, 'blue': 3}, {'green': 7, 'red': 8, 'blue': 9}]
# [{'green': 2, 'blue': 13}, {'blue': 11, 'red': 16, 'green': 7}, {'blue': 13, 'green': 10, 'red': 8}, {'red': 18, 'green': 1, 'blue': 14}]
# [{'red': 10, 'green': 6}, {'blue': 1, 'red': 6, 'green': 15}, {'green': 15, 'red': 9, 'blue': 3}, {'blue': 3, 'red': 11, 'green': 9}, {'blue': 2, 'red': 5, 'green': 10}]
# [{'green': 1, 'red': 5, 'blue': 8}, {'red': 4, 'green': 6, 'blue': 7}, {'blue': 13, 'green': 10, 'red': 6}, {'blue': 9, 'red': 2, 'green': 14}, {'green': 16, 'blue': 10, 'red': 1}, {'blue': 9, 'red': 3, 'green': 11}]
# [{'blue': 4}, {'green': 1, 'red': 1, 'blue': 16}, {'blue': 15, 'red': 1}]
# [{'blue': 2, 'green': 6}, {'green': 15, 'blue': 2, 'red': 10}, {'green': 1, 'blue': 6, 'red': 6}, {'red': 8, 'green': 1}, {'green': 4, 'blue': 3, 'red': 10}, {'red': 7, 'blue': 3, 'green': 20}]
# [{'red': 1, 'blue': 13, 'green': 8}, {'blue': 3, 'red': 7, 'green': 8}, {'red': 3, 'green': 11, 'blue': 12}, {'green': 7, 'blue': 6, 'red': 2}, {'blue': 11, 'red': 5, 'green': 10}, {'blue': 13, 'green': 3, 'red': 8}]
# [{'red': 4, 'green': 6, 'blue': 8}, {'red': 4, 'blue': 10, 'green': 9}, {'red': 5, 'blue': 2, 'green': 3}, {'green': 2, 'red': 9, 'blue': 4}]
# [{'red': 14, 'green': 4, 'blue': 5}, {'blue': 3, 'red': 2, 'green': 3}, {'red': 1, 'blue': 9, 'green': 1}, {'green': 5, 'red': 15, 'blue': 8}, {'green': 5, 'red': 6, 'blue': 6}]
# [{'blue': 1, 'green': 1, 'red': 9}, {'green': 4, 'blue': 1, 'red': 1}, {'green': 4, 'red': 4}, {'green': 5, 'red': 4}, {'green': 1, 'blue': 1, 'red': 8}, {'red': 9}]
# [{'red': 11, 'blue': 3, 'green': 19}, {'green': 3, 'red': 13, 'blue': 5}, {'blue': 8, 'red': 16, 'green': 18}, {'red': 13, 'blue': 5, 'green': 7}, {'red': 8, 'green': 5, 'blue': 4}, {'green': 16, 'blue': 1, 'red': 15}]
# [{'red': 12, 'blue': 15, 'green': 1}, {'green': 3, 'red': 10, 'blue': 5}, {'green': 4, 'blue': 5, 'red': 17}, {'red': 11, 'blue': 2}, {'blue': 6, 'green': 3, 'red': 4}, {'blue': 1, 'red': 13}]
# [{'blue': 2, 'green': 2, 'red': 3}, {'green': 1, 'red': 4}, {'red': 1, 'blue': 2}, {'green': 1, 'blue': 1, 'red': 2}]
# [{'green': 3, 'blue': 5, 'red': 4}, {'red': 3, 'green': 1}, {'blue': 3, 'red': 4, 'green': 3}, {'blue': 8, 'red': 8}, {'blue': 6}, {'green': 1, 'blue': 6, 'red': 1}]
# [{'blue': 3, 'green': 12, 'red': 2}, {'red': 13, 'green': 12, 'blue': 4}, {'green': 9, 'red': 1}, {'red': 10}, {'green': 12, 'red': 9}, {'red': 15, 'blue': 3, 'green': 10}]
# [{'green': 1, 'blue': 8}, {'red': 3, 'green': 7}, {'red': 4, 'green': 3}, {'red': 5, 'green': 9}]
# [{'blue': 12, 'red': 3, 'green': 2}, {'blue': 12, 'green': 12, 'red': 2}, {'blue': 10, 'green': 8}, {'red': 3, 'green': 3, 'blue': 9}]
# [{'red': 4, 'blue': 4, 'green': 6}, {'blue': 3, 'green': 8, 'red': 2}, {'green': 5, 'red': 2, 'blue': 2}]
# [{'blue': 12, 'red': 4, 'green': 5}, {'blue': 18, 'red': 2, 'green': 5}, {'green': 2, 'red': 2}, {'red': 3, 'green': 9, 'blue': 13}, {'green': 2, 'blue': 12, 'red': 1}]
# [{'red': 8, 'blue': 3}, {'blue': 6, 'red': 5}, {'red': 9, 'blue': 10, 'green': 3}, {'green': 4, 'red': 10}]
# [{'green': 1, 'blue': 3, 'red': 7}, {'blue': 6, 'green': 6, 'red': 9}, {'green': 5}]
# [{'red': 7, 'blue': 1, 'green': 1}, {'red': 5, 'blue': 2, 'green': 3}, {'red': 9, 'blue': 9}, {'red': 5, 'green': 3, 'blue': 1}, {'green': 1, 'red': 9, 'blue': 1}]
# [{'blue': 1, 'green': 1, 'red': 3}, {'red': 3, 'green': 2, 'blue': 2}, {'red': 5, 'blue': 1, 'green': 8}, {'green': 2, 'red': 4, 'blue': 2}, {'red': 13, 'green': 2}]
# [{'blue': 17, 'red': 5, 'green': 3}, {'green': 10, 'red': 4, 'blue': 5}, {'red': 3, 'blue': 17, 'green': 1}, {'blue': 11, 'red': 10, 'green': 3}]
# [{'blue': 8, 'green': 2, 'red': 7}, {'blue': 4, 'red': 1}, {'red': 9, 'green': 2, 'blue': 6}, {'blue': 4, 'red': 9}, {'green': 1, 'blue': 9, 'red': 8}, {'red': 6, 'green': 1}]
# [{'green': 1, 'blue': 6, 'red': 14}, {'green': 7, 'blue': 1, 'red': 8}, {'green': 3, 'red': 16, 'blue': 7}]
# [{'red': 5, 'blue': 5}, {'green': 1, 'red': 8, 'blue': 9}, {'red': 6, 'blue': 3}]
# [{'green': 4, 'red': 17, 'blue': 14}, {'red': 14, 'green': 2, 'blue': 2}, {'blue': 9, 'green': 1, 'red': 8}]
# [{'blue': 1, 'red': 10, 'green': 7}, {'red': 3, 'blue': 4}, {'blue': 2, 'green': 1, 'red': 1}]
# [{'red': 8, 'green': 2, 'blue': 13}, {'red': 10, 'blue': 9}, {'green': 4, 'blue': 15, 'red': 2}, {'blue': 1, 'green': 1, 'red': 16}]
# [{'red': 9, 'green': 8, 'blue': 1}, {'green': 10, 'red': 5}, {'red': 9, 'green': 3, 'blue': 1}, {'red': 8, 'green': 1}]
# [{'blue': 11, 'green': 18, 'red': 1}, {'red': 13, 'blue': 9}, {'green': 17, 'red': 18, 'blue': 6}]
# [{'green': 2, 'red': 10, 'blue': 6}, {'red': 6, 'blue': 6, 'green': 7}, {'red': 7, 'green': 5, 'blue': 3}, {'green': 5, 'red': 2, 'blue': 1}]
# [{'blue': 1, 'green': 9, 'red': 7}, {'blue': 2, 'red': 11, 'green': 10}, {'blue': 1, 'green': 9, 'red': 12}, {'red': 10, 'green': 5, 'blue': 3}, {'green': 9, 'blue': 3, 'red': 14}]
# [{'green': 4}, {'blue': 6}, {'green': 4, 'blue': 7}, {'blue': 1}, {'red': 1, 'green': 8, 'blue': 1}]
# [{'green': 6, 'blue': 3, 'red': 13}, {'blue': 3, 'green': 2, 'red': 16}, {'red': 13, 'green': 9, 'blue': 2}, {'red': 1, 'blue': 1, 'green': 7}]
# [{'green': 1, 'blue': 4, 'red': 10}, {'red': 2, 'blue': 6}, {'blue': 2, 'red': 5}, {'blue': 3, 'red': 7, 'green': 1}]
# [{'red': 17}, {'red': 18, 'blue': 3, 'green': 4}, {'blue': 5, 'red': 14, 'green': 1}, {'green': 4, 'blue': 5, 'red': 4}, {'green': 2, 'red': 18}]
# [{'green': 14, 'red': 2, 'blue': 18}, {'green': 8, 'blue': 12, 'red': 2}, {'red': 1, 'blue': 13, 'green': 12}]
# [{'green': 2, 'blue': 4, 'red': 12}, {'green': 1, 'red': 3, 'blue': 4}, {'green': 4, 'red': 2, 'blue': 3}, {'green': 3, 'red': 6}, {'red': 3, 'blue': 3, 'green': 3}]
# [{'blue': 2, 'red': 5, 'green': 2}, {'red': 6, 'green': 6}, {'red': 8, 'green': 11, 'blue': 2}, {'green': 9, 'blue': 1, 'red': 11}, {'blue': 2, 'green': 17, 'red': 11}, {'red': 7, 'green': 8, 'blue': 2}]
# [{'blue': 4, 'red': 1, 'green': 16}, {'blue': 2, 'green': 5, 'red': 1}, {'green': 2, 'blue': 6}, {'blue': 3, 'green': 10}, {'green': 14, 'blue': 6}, {'red': 1, 'green': 11}]
# [{'red': 4, 'blue': 1, 'green': 5}, {'green': 2, 'blue': 6}, {'red': 1, 'green': 17}, {'red': 2, 'blue': 11, 'green': 14}, {'red': 2, 'blue': 8, 'green': 14}]
# [{'red': 6, 'blue': 7, 'green': 1}, {'red': 2, 'green': 10, 'blue': 16}, {'blue': 14, 'green': 10, 'red': 7}, {'red': 12, 'blue': 15, 'green': 3}, {'blue': 5, 'red': 1}]
# [{'blue': 9, 'red': 4}, {'green': 1, 'blue': 2, 'red': 4}, {'red': 8, 'blue': 9}, {'red': 6, 'blue': 15}, {'blue': 7, 'red': 10}]
# [{'green': 8, 'red': 2, 'blue': 4}, {'red': 2, 'green': 1, 'blue': 3}, {'red': 1, 'green': 3}, {'blue': 2, 'green': 9}]
# [{'green': 4, 'red': 13}, {'red': 2, 'green': 6, 'blue': 2}, {'red': 4, 'green': 6, 'blue': 2}, {'red': 6, 'blue': 2}, {'red': 5, 'green': 9}, {'red': 3, 'blue': 1, 'green': 10}]
# [{'blue': 8, 'red': 3, 'green': 3}, {'red': 6, 'green': 8}, {'blue': 6, 'green': 7, 'red': 7}]
# [{'red': 6, 'blue': 2, 'green': 2}, {'green': 15, 'red': 11, 'blue': 1}, {'red': 1, 'blue': 2, 'green': 10}, {'blue': 2, 'green': 17}, {'green': 12, 'blue': 2, 'red': 4}, {'green': 16, 'red': 10, 'blue': 3}]
# [{'green': 1, 'red': 2, 'blue': 12}, {'red': 2, 'blue': 3, 'green': 3}, {'blue': 8, 'green': 4, 'red': 1}, {'blue': 12, 'red': 2, 'green': 4}, {'red': 2, 'blue': 10}]
# [{'red': 6, 'green': 4, 'blue': 16}, {'red': 9, 'green': 7, 'blue': 11}, {'blue': 7, 'green': 16, 'red': 15}, {'red': 2, 'green': 2}, {'red': 16}, {'red': 13, 'green': 15, 'blue': 2}]
# [{'red': 14, 'blue': 3, 'green': 14}, {'blue': 4, 'green': 18, 'red': 2}, {'green': 4, 'blue': 9, 'red': 7}, {'green': 15, 'blue': 9, 'red': 10}]
# [{'green': 2, 'red': 5, 'blue': 12}, {'green': 3, 'red': 5, 'blue': 4}, {'blue': 5, 'red': 4}, {'red': 6, 'blue': 11}, {'red': 5, 'blue': 2}, {'blue': 5, 'green': 1, 'red': 4}]
# [{'green': 3, 'red': 3}, {'green': 6, 'blue': 11, 'red': 2}, {'red': 6, 'blue': 4}]
# [{'blue': 9, 'green': 4, 'red': 4}, {'blue': 5, 'red': 5, 'green': 3}, {'blue': 9, 'green': 11, 'red': 3}]
# [{'blue': 1, 'red': 13}, {'red': 12}, {'red': 5, 'green': 1, 'blue': 6}, {'blue': 5, 'red': 7}, {'red': 8, 'blue': 9}]
# [{'green': 7, 'red': 17, 'blue': 3}, {'red': 15, 'green': 2}, {'red': 5, 'blue': 3, 'green': 1}, {'red': 19, 'blue': 1}, {'red': 3, 'blue': 1, 'green': 6}, {'red': 7, 'blue': 3, 'green': 1}]
# [{'blue': 11, 'green': 9, 'red': 4}, {'green': 5, 'red': 2, 'blue': 16}, {'blue': 13, 'red': 2}, {'red': 3, 'blue': 18, 'green': 1}]
# [{'green': 5, 'red': 13, 'blue': 10}, {'red': 5, 'green': 11}, {'red': 1, 'green': 5, 'blue': 8}, {'red': 4, 'green': 14}, {'blue': 7, 'green': 12, 'red': 2}]
# [{'blue': 5, 'green': 2, 'red': 3}, {'red': 2}, {'green': 1, 'blue': 6}, {'blue': 5, 'red': 1}]
# [{'red': 9, 'green': 7}, {'red': 10, 'blue': 2, 'green': 6}, {'red': 13, 'blue': 3, 'green': 15}, {'blue': 9, 'green': 10, 'red': 2}, {'blue': 1, 'red': 4, 'green': 12}]
# [{'red': 4, 'green': 3}, {'blue': 3, 'green': 10, 'red': 4}, {'red': 1, 'green': 12, 'blue': 7}, {'blue': 5, 'green': 3, 'red': 6}, {'green': 10, 'blue': 1, 'red': 5}, {'green': 5, 'red': 5}]
# [{'blue': 3, 'green': 18}, {'blue': 5, 'green': 11, 'red': 3}, {'blue': 2, 'green': 13, 'red': 7}, {'red': 4, 'blue': 1, 'green': 8}]
# [{'green': 9, 'blue': 18, 'red': 10}, {'red': 6, 'green': 5, 'blue': 13}, {'red': 8, 'blue': 4, 'green': 7}]
# [{'green': 9, 'red': 2, 'blue': 2}, {'green': 7, 'red': 2, 'blue': 1}, {'green': 2, 'red': 2, 'blue': 2}, {'red': 2, 'green': 14, 'blue': 1}]
# [{'red': 10, 'green': 7, 'blue': 3}, {'green': 4, 'red': 12, 'blue': 12}, {'blue': 13, 'green': 1, 'red': 8}]
# [{'green': 10, 'blue': 3}, {'green': 8, 'red': 2}, {'blue': 3, 'green': 5}, {'blue': 3, 'green': 1}, {'blue': 5, 'green': 7, 'red': 1}, {'green': 8, 'blue': 5, 'red': 2}]
# [{'blue': 6, 'green': 4, 'red': 5}, {'green': 11, 'blue': 1, 'red': 13}, {'green': 11, 'red': 1}, {'green': 6, 'red': 2}, {'blue': 1, 'green': 5, 'red': 4}]
# [{'blue': 1, 'red': 10}, {'blue': 2, 'red': 5}, {'red': 1, 'blue': 2, 'green': 2}]
# [{'green': 11, 'red': 13, 'blue': 6}, {'blue': 8, 'red': 2, 'green': 6}, {'blue': 10, 'red': 11, 'green': 1}, {'green': 16, 'blue': 16, 'red': 6}, {'green': 6, 'red': 12, 'blue': 3}]
# [{'green': 15, 'red': 4, 'blue': 2}, {'red': 6, 'green': 13, 'blue': 4}, {'green': 3, 'red': 17, 'blue': 4}, {'blue': 4, 'green': 14}]
# [{'green': 6, 'red': 12, 'blue': 7}, {'blue': 3, 'green': 6, 'red': 7}, {'green': 6, 'red': 13, 'blue': 5}, {'red': 6, 'green': 7}]
# [{'blue': 19, 'red': 19}, {'blue': 6, 'red': 12, 'green': 6}, {'green': 2, 'blue': 7, 'red': 17}, {'green': 3, 'blue': 9, 'red': 7}, {'red': 8, 'green': 7, 'blue': 18}]
# [{'red': 3, 'green': 1}, {'red': 14, 'blue': 2, 'green': 2}, {'red': 7, 'blue': 3}, {'blue': 1, 'red': 6}]
# [{'green': 2, 'red': 16, 'blue': 15}, {'green': 3, 'blue': 3, 'red': 11}, {'blue': 7, 'red': 6}, {'blue': 7, 'red': 13}]
# [{'red': 1, 'blue': 1, 'green': 9}, {'green': 12, 'red': 3, 'blue': 4}, {'green': 3, 'red': 3, 'blue': 7}]
# [{'green': 12, 'red': 5, 'blue': 9}, {'blue': 3, 'green': 3, 'red': 2}, {'green': 5, 'blue': 2}, {'green': 5, 'red': 7, 'blue': 10}, {'red': 7, 'blue': 10, 'green': 10}]
# [{'blue': 3, 'red': 15, 'green': 10}, {'blue': 3, 'red': 16}, {'blue': 1, 'green': 13, 'red': 6}]
# [{'blue': 11, 'green': 2, 'red': 5}, {'green': 2, 'red': 10, 'blue': 15}, {'blue': 11, 'red': 19, 'green': 8}]
# [{'green': 7, 'red': 2, 'blue': 1}, {'red': 5, 'blue': 3, 'green': 12}, {'blue': 4, 'green': 2, 'red': 3}]
# [{'green': 2, 'blue': 5, 'red': 9}, {'green': 4, 'blue': 9, 'red': 8}, {'green': 7, 'blue': 11, 'red': 7}]
# [{'green': 2, 'blue': 15, 'red': 2}, {'red': 2, 'green': 6, 'blue': 12}, {'green': 11, 'blue': 18, 'red': 2}, {'red': 3, 'blue': 9, 'green': 3}, {'blue': 18}]
# [{'red': 13, 'green': 2}, {'red': 15, 'green': 1}, {'green': 4, 'blue': 1}, {'red': 11, 'green': 5}, {'green': 3, 'red': 8}]

# %% [markdown]
# Extract minimum set of cubes from each game. each game is an array of dictionaries

# %%
print(min)
min_set = []

for i in games:
    #print(i)
    min = {'red': 0, 'green': 0, 'blue': 0}
    for j in i:
        #print(j)
        for key in desired_order:
            if key in j:
                #print(j[key])
                if j[key] > min[key]:
                    print(f'key1 : {key}')
                    print(f'j[key]: {j[key]}, min[key]: {min[key]}')
                    min[key] = j[key]
                    print(f'min[key]: {min[key]}')
            else:
                print('Ex')
                
        print(f'newmin: {min}')
        print('Cycle end')
                
                
    min_set.append(min)
# Out:
# {'red': 6, 'green': 3, 'blue': 2}
# key1 : red
# j[key]: 7, min[key]: 0
# min[key]: 7
# key1 : green
# j[key]: 2, min[key]: 0
# min[key]: 2
# key1 : blue
# j[key]: 6, min[key]: 0
# min[key]: 6
# newmin: {'red': 7, 'green': 2, 'blue': 6}
# Cycle end
# key1 : green
# j[key]: 12, min[key]: 2
# min[key]: 12
# newmin: {'red': 7, 'green': 12, 'blue': 6}
# Cycle end
# key1 : green
# j[key]: 18, min[key]: 12
# min[key]: 18
# newmin: {'red': 7, 'green': 18, 'blue': 6}
# Cycle end
# key1 : red
# j[key]: 4, min[key]: 0
# min[key]: 4
# key1 : green
# j[key]: 10, min[key]: 0
# min[key]: 10
# Ex
# newmin: {'red': 4, 'green': 10, 'blue': 0}
# Cycle end
# Ex
# Ex
# newmin: {'red': 4, 'green': 10, 'blue': 0}
# Cycle end
# key1 : red
# j[key]: 11, min[key]: 4
# min[key]: 11
# key1 : green
# j[key]: 12, min[key]: 10
# min[key]: 12
# key1 : blue
# j[key]: 1, min[key]: 0
# min[key]: 1
# newmin: {'red': 11, 'green': 12, 'blue': 1}
# Cycle end
# newmin: {'red': 11, 'green': 12, 'blue': 1}
# Cycle end
# newmin: {'red': 11, 'green': 12, 'blue': 1}
# Cycle end
# Ex
# key1 : green
# j[key]: 3, min[key]: 0
# min[key]: 3
# Ex
# newmin: {'red': 0, 'green': 3, 'blue': 0}
# Cycle end
# key1 : red
# j[key]: 15, min[key]: 0
# min[key]: 15
# key1 : blue
# j[key]: 7, min[key]: 0
# min[key]: 7
# newmin: {'red': 15, 'green': 3, 'blue': 7}
# Cycle end
# newmin: {'red': 15, 'green': 3, 'blue': 7}
# Cycle end
# key1 : blue
# j[key]: 14, min[key]: 7
# min[key]: 14
# newmin: {'red': 15, 'green': 3, 'blue': 14}
# Cycle end
# newmin: {'red': 15, 'green': 3, 'blue': 14}
# Cycle end
# key1 : red
# j[key]: 16, min[key]: 15
# min[key]: 16
# newmin: {'red': 16, 'green': 3, 'blue': 14}
# Cycle end
# Ex
# Ex
# key1 : blue
# j[key]: 5, min[key]: 0
# min[key]: 5
# newmin: {'red': 0, 'green': 0, 'blue': 5}
# Cycle end
# key1 : red
# j[key]: 7, min[key]: 0
# min[key]: 7
# Ex
# key1 : blue
# j[key]: 8, min[key]: 5
# min[key]: 8
# newmin: {'red': 7, 'green': 0, 'blue': 8}
# Cycle end
# key1 : green
# j[key]: 4, min[key]: 0
# min[key]: 4
# key1 : blue
# j[key]: 9, min[key]: 8
# min[key]: 9
# newmin: {'red': 7, 'green': 4, 'blue': 9}
# Cycle end
# Ex
# newmin: {'red': 7, 'green': 4, 'blue': 9}
# Cycle end
# key1 : red
# j[key]: 8, min[key]: 7
# min[key]: 8
# Ex
# newmin: {'red': 8, 'green': 4, 'blue': 9}
# Cycle end
# newmin: {'red': 8, 'green': 4, 'blue': 9}
# Cycle end
# key1 : red
# j[key]: 4, min[key]: 0
# min[key]: 4
# key1 : green
# j[key]: 10, min[key]: 0
# min[key]: 10
# key1 : blue
# j[key]: 3, min[key]: 0
# min[key]: 3
# newmin: {'red': 4, 'green': 10, 'blue': 3}
# Cycle end
# key1 : green
# j[key]: 13, min[key]: 10
# min[key]: 13
# key1 : blue
# j[key]: 8, min[key]: 3
# min[key]: 8
# newmin: {'red': 4, 'green': 13, 'blue': 8}
# Cycle end
# newmin: {'red': 4, 'green': 13, 'blue': 8}
# Cycle end
# newmin: {'red': 4, 'green': 13, 'blue': 8}
# Cycle end
# key1 : blue
# j[key]: 13, min[key]: 8
# min[key]: 13
# newmin: {'red': 4, 'green': 13, 'blue': 13}
# Cycle end
# Ex
# newmin: {'red': 4, 'green': 13, 'blue': 13}
# Cycle end
# key1 : red
# j[key]: 3, min[key]: 0
# min[key]: 3
# Ex
# key1 : blue
# j[key]: 2, min[key]: 0
# min[key]: 2
# newmin: {'red': 3, 'green': 0, 'blue': 2}
# Cycle end
# Ex
# key1 : green
# j[key]: 6, min[key]: 0
# min[key]: 6
# key1 : blue
# j[key]: 13, min[key]: 2
# min[key]: 13
# newmin: {'red': 3, 'green': 6, 'blue': 13}
# Cycle end
# Ex
# newmin: {'red': 3, 'green': 6, 'blue': 13}
# Cycle end
# newmin: {'red': 3, 'green': 6, 'blue': 13}
# Cycle end
# key1 : red
# j[key]: 2, min[key]: 0
# min[key]: 2
# key1 : green
# j[key]: 14, min[key]: 0
# min[key]: 14
# key1 : blue
# j[key]: 5, min[key]: 0
# min[key]: 5
# newmin: {'red': 2, 'green': 14, 'blue': 5}
# Cycle end
# Ex
# newmin: {'red': 2, 'green': 14, 'blue': 5}
# Cycle end
# key1 : blue
# j[key]: 9, min[key]: 5
# min[key]: 9
# newmin: {'red': 2, 'green': 14, 'blue': 9}
# Cycle end
# Ex
# key1 : green
# j[key]: 10, min[key]: 0
# min[key]: 10
# key1 : blue
# j[key]: 6, min[key]: 0
# min[key]: 6
# newmin: {'red': 0, 'green': 10, 'blue': 6}
# Cycle end
# key1 : red
# j[key]: 4, min[key]: 0
# min[key]: 4
# Ex
# newmin: {'red': 4, 'green': 10, 'blue': 6}
# Cycle end
# key1 : red
# j[key]: 7, min[key]: 4
# min[key]: 7
# key1 : blue
# j[key]: 7, min[key]: 6
# min[key]: 7
# newmin: {'red': 7, 'green': 10, 'blue': 7}
# Cycle end
# key1 : green
# j[key]: 11, min[key]: 10
# min[key]: 11
# Ex
# newmin: {'red': 7, 'green': 11, 'blue': 7}
# Cycle end
# newmin: {'red': 7, 'green': 11, 'blue': 7}
# Cycle end
# key1 : red
# j[key]: 6, min[key]: 0
# min[key]: 6
# key1 : green
# j[key]: 1, min[key]: 0
# min[key]: 1
# key1 : blue
# j[key]: 4, min[key]: 0
# min[key]: 4
# newmin: {'red': 6, 'green': 1, 'blue': 4}
# Cycle end
# Ex
# key1 : blue
# j[key]: 5, min[key]: 4
# min[key]: 5
# newmin: {'red': 6, 'green': 1, 'blue': 5}
# Cycle end
# key1 : red
# j[key]: 7, min[key]: 6
# min[key]: 7
# Ex
# newmin: {'red': 7, 'green': 1, 'blue': 5}
# Cycle end
# Ex
# key1 : blue
# j[key]: 8, min[key]: 5
# min[key]: 8
# newmin: {'red': 7, 'green': 1, 'blue': 8}
# Cycle end
# Ex
# Ex
# newmin: {'red': 7, 'green': 1, 'blue': 8}
# Cycle end
# key1 : red
# j[key]: 6, min[key]: 0
# min[key]: 6
# key1 : green
# j[key]: 3, min[key]: 0
# min[key]: 3
# key1 : blue
# j[key]: 7, min[key]: 0
# min[key]: 7
# newmin: {'red': 6, 'green': 3, 'blue': 7}
# Cycle end
# Ex
# newmin: {'red': 6, 'green': 3, 'blue': 7}
# Cycle end
# Ex
# Ex
# newmin: {'red': 6, 'green': 3, 'blue': 7}
# Cycle end
# key1 : green
# j[key]: 5, min[key]: 3
# min[key]: 5
# newmin: {'red': 6, 'green': 5, 'blue': 7}
# Cycle end
# Ex
# newmin: {'red': 6, 'green': 5, 'blue': 7}
# Cycle end
# key1 : green
# j[key]: 6, min[key]: 5
# min[key]: 6
# newmin: {'red': 6, 'green': 6, 'blue': 7}
# Cycle end
# key1 : red
# j[key]: 8, min[key]: 0
# min[key]: 8
# key1 : green
# j[key]: 6, min[key]: 0
# min[key]: 6
# key1 : blue
# j[key]: 6, min[key]: 0
# min[key]: 6
# newmin: {'red': 8, 'green': 6, 'blue': 6}
# Cycle end
# newmin: {'red': 8, 'green': 6, 'blue': 6}
# Cycle end
# Ex
# newmin: {'red': 8, 'green': 6, 'blue': 6}
# Cycle end
# key1 : green
# j[key]: 8, min[key]: 6
# min[key]: 8
# newmin: {'red': 8, 'green': 8, 'blue': 6}
# Cycle end
# key1 : red
# j[key]: 1, min[key]: 0
# min[key]: 1
# key1 : green
# j[key]: 5, min[key]: 0
# min[key]: 5
# key1 : blue
# j[key]: 7, min[key]: 0
# min[key]: 7
# newmin: {'red': 1, 'green': 5, 'blue': 7}
# Cycle end
# key1 : green
# j[key]: 10, min[key]: 5
# min[key]: 10
# Ex
# newmin: {'red': 1, 'green': 10, 'blue': 7}
# Cycle end
# key1 : red
# j[key]: 6, min[key]: 1
# min[key]: 6
# newmin: {'red': 6, 'green': 10, 'blue': 7}
# Cycle end
# newmin: {'red': 6, 'green': 10, 'blue': 7}
# Cycle end
# Ex
# newmin: {'red': 6, 'green': 10, 'blue': 7}
# Cycle end
# newmin: {'red': 6, 'green': 10, 'blue': 7}
# Cycle end
# key1 : red
# j[key]: 11, min[key]: 0
# min[key]: 11
# key1 : green
# j[key]: 16, min[key]: 0
# min[key]: 16
# key1 : blue
# j[key]: 9, min[key]: 0
# min[key]: 9
# newmin: {'red': 11, 'green': 16, 'blue': 9}
# Cycle end
# newmin: {'red': 11, 'green': 16, 'blue': 9}
# Cycle end
# newmin: {'red': 11, 'green': 16, 'blue': 9}
# Cycle end
# key1 : red
# j[key]: 4, min[key]: 0
# min[key]: 4
# key1 : green
# j[key]: 12, min[key]: 0
# min[key]: 12
# key1 : blue
# j[key]: 8, min[key]: 0
# min[key]: 8
# newmin: {'red': 4, 'green': 12, 'blue': 8}
# Cycle end
# newmin: {'red': 4, 'green': 12, 'blue': 8}
# Cycle end
# key1 : red
# j[key]: 6, min[key]: 4
# min[key]: 6
# newmin: {'red': 6, 'green': 12, 'blue': 8}
# Cycle end
# key1 : blue
# j[key]: 11, min[key]: 8
# min[key]: 11
# newmin: {'red': 6, 'green': 12, 'blue': 11}
# Cycle end
# key1 : red
# j[key]: 6, min[key]: 0
# min[key]: 6
# Ex
# Ex
# newmin: {'red': 6, 'green': 0, 'blue': 0}
# Cycle end
# Ex
# key1 : blue
# j[key]: 5, min[key]: 0
# min[key]: 5
# newmin: {'red': 6, 'green': 0, 'blue': 5}
# Cycle end
# key1 : green
# j[key]: 1, min[key]: 0
# min[key]: 1
# key1 : blue
# j[key]: 10, min[key]: 5
# min[key]: 10
# newmin: {'red': 6, 'green': 1, 'blue': 10}
# Cycle end
# key1 : red
# j[key]: 8, min[key]: 6
# min[key]: 8
# key1 : green
# j[key]: 2, min[key]: 1
# min[key]: 2
# newmin: {'red': 8, 'green': 2, 'blue': 10}
# Cycle end
# key1 : red
# j[key]: 4, min[key]: 0
# min[key]: 4
# key1 : green
# j[key]: 2, min[key]: 0
# min[key]: 2
# key1 : blue
# j[key]: 6, min[key]: 0
# min[key]: 6
# newmin: {'red': 4, 'green': 2, 'blue': 6}
# Cycle end
# key1 : blue
# j[key]: 16, min[key]: 6
# min[key]: 16
# newmin: {'red': 4, 'green': 2, 'blue': 16}
# Cycle end
# key1 : green
# j[key]: 7, min[key]: 2
# min[key]: 7
# newmin: {'red': 4, 'green': 7, 'blue': 16}
# Cycle end
# Ex
# Ex
# key1 : blue
# j[key]: 5, min[key]: 0
# min[key]: 5
# newmin: {'red': 0, 'green': 0, 'blue': 5}
# Cycle end
# Ex
# Ex
# newmin: {'red': 0, 'green': 0, 'blue': 5}
# Cycle end
# key1 : red
# j[key]: 2, min[key]: 0
# min[key]: 2
# key1 : green
# j[key]: 2, min[key]: 0
# min[key]: 2
# newmin: {'red': 2, 'green': 2, 'blue': 5}
# Cycle end
# key1 : green
# j[key]: 4, min[key]: 2
# min[key]: 4
# key1 : blue
# j[key]: 6, min[key]: 5
# min[key]: 6
# newmin: {'red': 2, 'green': 4, 'blue': 6}
# Cycle end
# key1 : red
# j[key]: 3, min[key]: 0
# min[key]: 3
# Ex
# Ex
# newmin: {'red': 3, 'green': 0, 'blue': 0}
# Cycle end
# key1 : red
# j[key]: 11, min[key]: 3
# min[key]: 11
# key1 : green
# j[key]: 7, min[key]: 0
# min[key]: 7
# key1 : blue
# j[key]: 6, min[key]: 0
# min[key]: 6
# newmin: {'red': 11, 'green': 7, 'blue': 6}
# Cycle end
# key1 : green
# j[key]: 12, min[key]: 7
# min[key]: 12
# newmin: {'red': 11, 'green': 12, 'blue': 6}
# Cycle end
# Ex
# newmin: {'red': 11, 'green': 12, 'blue': 6}
# Cycle end
# key1 : blue
# j[key]: 9, min[key]: 6
# min[key]: 9
# newmin: {'red': 11, 'green': 12, 'blue': 9}
# Cycle end
# Ex
# key1 : green
# j[key]: 2, min[key]: 0
# min[key]: 2
# key1 : blue
# j[key]: 13, min[key]: 0
# min[key]: 13
# newmin: {'red': 0, 'green': 2, 'blue': 13}
# Cycle end
# key1 : red
# j[key]: 16, min[key]: 0
# min[key]: 16
# key1 : green
# j[key]: 7, min[key]: 2
# min[key]: 7
# newmin: {'red': 16, 'green': 7, 'blue': 13}
# Cycle end
# key1 : green
# j[key]: 10, min[key]: 7
# min[key]: 10
# newmin: {'red': 16, 'green': 10, 'blue': 13}
# Cycle end
# key1 : red
# j[key]: 18, min[key]: 16
# min[key]: 18
# key1 : blue
# j[key]: 14, min[key]: 13
# min[key]: 14
# newmin: {'red': 18, 'green': 10, 'blue': 14}
# Cycle end
# key1 : red
# j[key]: 10, min[key]: 0
# min[key]: 10
# key1 : green
# j[key]: 6, min[key]: 0
# min[key]: 6
# Ex
# newmin: {'red': 10, 'green': 6, 'blue': 0}
# Cycle end
# key1 : green
# j[key]: 15, min[key]: 6
# min[key]: 15
# key1 : blue
# j[key]: 1, min[key]: 0
# min[key]: 1
# newmin: {'red': 10, 'green': 15, 'blue': 1}
# Cycle end
# key1 : blue
# j[key]: 3, min[key]: 1
# min[key]: 3
# newmin: {'red': 10, 'green': 15, 'blue': 3}
# Cycle end
# key1 : red
# j[key]: 11, min[key]: 10
# min[key]: 11
# newmin: {'red': 11, 'green': 15, 'blue': 3}
# Cycle end
# newmin: {'red': 11, 'green': 15, 'blue': 3}
# Cycle end
# key1 : red
# j[key]: 5, min[key]: 0
# min[key]: 5
# key1 : green
# j[key]: 1, min[key]: 0
# min[key]: 1
# key1 : blue
# j[key]: 8, min[key]: 0
# min[key]: 8
# newmin: {'red': 5, 'green': 1, 'blue': 8}
# Cycle end
# key1 : green
# j[key]: 6, min[key]: 1
# min[key]: 6
# newmin: {'red': 5, 'green': 6, 'blue': 8}
# Cycle end
# key1 : red
# j[key]: 6, min[key]: 5
# min[key]: 6
# key1 : green
# j[key]: 10, min[key]: 6
# min[key]: 10
# key1 : blue
# j[key]: 13, min[key]: 8
# min[key]: 13
# newmin: {'red': 6, 'green': 10, 'blue': 13}
# Cycle end
# key1 : green
# j[key]: 14, min[key]: 10
# min[key]: 14
# newmin: {'red': 6, 'green': 14, 'blue': 13}
# Cycle end
# key1 : green
# j[key]: 16, min[key]: 14
# min[key]: 16
# newmin: {'red': 6, 'green': 16, 'blue': 13}
# Cycle end
# newmin: {'red': 6, 'green': 16, 'blue': 13}
# Cycle end
# Ex
# Ex
# key1 : blue
# j[key]: 4, min[key]: 0
# min[key]: 4
# newmin: {'red': 0, 'green': 0, 'blue': 4}
# Cycle end
# key1 : red
# j[key]: 1, min[key]: 0
# min[key]: 1
# key1 : green
# j[key]: 1, min[key]: 0
# min[key]: 1
# key1 : blue
# j[key]: 16, min[key]: 4
# min[key]: 16
# newmin: {'red': 1, 'green': 1, 'blue': 16}
# Cycle end
# Ex
# newmin: {'red': 1, 'green': 1, 'blue': 16}
# Cycle end
# Ex
# key1 : green
# j[key]: 6, min[key]: 0
# min[key]: 6
# key1 : blue
# j[key]: 2, min[key]: 0
# min[key]: 2
# newmin: {'red': 0, 'green': 6, 'blue': 2}
# Cycle end
# key1 : red
# j[key]: 10, min[key]: 0
# min[key]: 10
# key1 : green
# j[key]: 15, min[key]: 6
# min[key]: 15
# newmin: {'red': 10, 'green': 15, 'blue': 2}
# Cycle end
# key1 : blue
# j[key]: 6, min[key]: 2
# min[key]: 6
# newmin: {'red': 10, 'green': 15, 'blue': 6}
# Cycle end
# Ex
# newmin: {'red': 10, 'green': 15, 'blue': 6}
# Cycle end
# newmin: {'red': 10, 'green': 15, 'blue': 6}
# Cycle end
# key1 : green
# j[key]: 20, min[key]: 15
# min[key]: 20
# newmin: {'red': 10, 'green': 20, 'blue': 6}
# Cycle end
# key1 : red
# j[key]: 1, min[key]: 0
# min[key]: 1
# key1 : green
# j[key]: 8, min[key]: 0
# min[key]: 8
# key1 : blue
# j[key]: 13, min[key]: 0
# min[key]: 13
# newmin: {'red': 1, 'green': 8, 'blue': 13}
# Cycle end
# key1 : red
# j[key]: 7, min[key]: 1
# min[key]: 7
# newmin: {'red': 7, 'green': 8, 'blue': 13}
# Cycle end
# key1 : green
# j[key]: 11, min[key]: 8
# min[key]: 11
# newmin: {'red': 7, 'green': 11, 'blue': 13}
# Cycle end
# newmin: {'red': 7, 'green': 11, 'blue': 13}
# Cycle end
# newmin: {'red': 7, 'green': 11, 'blue': 13}
# Cycle end
# key1 : red
# j[key]: 8, min[key]: 7
# min[key]: 8
# newmin: {'red': 8, 'green': 11, 'blue': 13}
# Cycle end
# key1 : red
# j[key]: 4, min[key]: 0
# min[key]: 4
# key1 : green
# j[key]: 6, min[key]: 0
# min[key]: 6
# key1 : blue
# j[key]: 8, min[key]: 0
# min[key]: 8
# newmin: {'red': 4, 'green': 6, 'blue': 8}
# Cycle end
# key1 : green
# j[key]: 9, min[key]: 6
# min[key]: 9
# key1 : blue
# j[key]: 10, min[key]: 8
# min[key]: 10
# newmin: {'red': 4, 'green': 9, 'blue': 10}
# Cycle end
# key1 : red
# j[key]: 5, min[key]: 4
# min[key]: 5
# newmin: {'red': 5, 'green': 9, 'blue': 10}
# Cycle end
# key1 : red
# j[key]: 9, min[key]: 5
# min[key]: 9
# newmin: {'red': 9, 'green': 9, 'blue': 10}
# Cycle end
# key1 : red
# j[key]: 14, min[key]: 0
# min[key]: 14
# key1 : green
# j[key]: 4, min[key]: 0
# min[key]: 4
# key1 : blue
# j[key]: 5, min[key]: 0
# min[key]: 5
# newmin: {'red': 14, 'green': 4, 'blue': 5}
# Cycle end
# newmin: {'red': 14, 'green': 4, 'blue': 5}
# Cycle end
# key1 : blue
# j[key]: 9, min[key]: 5
# min[key]: 9
# newmin: {'red': 14, 'green': 4, 'blue': 9}
# Cycle end
# key1 : red
# j[key]: 15, min[key]: 14
# min[key]: 15
# key1 : green
# j[key]: 5, min[key]: 4
# min[key]: 5
# newmin: {'red': 15, 'green': 5, 'blue': 9}
# Cycle end
# newmin: {'red': 15, 'green': 5, 'blue': 9}
# Cycle end
# key1 : red
# j[key]: 9, min[key]: 0
# min[key]: 9
# key1 : green
# j[key]: 1, min[key]: 0
# min[key]: 1
# key1 : blue
# j[key]: 1, min[key]: 0
# min[key]: 1
# newmin: {'red': 9, 'green': 1, 'blue': 1}
# Cycle end
# key1 : green
# j[key]: 4, min[key]: 1
# min[key]: 4
# newmin: {'red': 9, 'green': 4, 'blue': 1}
# Cycle end
# Ex
# newmin: {'red': 9, 'green': 4, 'blue': 1}
# Cycle end
# key1 : green
# j[key]: 5, min[key]: 4
# min[key]: 5
# Ex
# newmin: {'red': 9, 'green': 5, 'blue': 1}
# Cycle end
# newmin: {'red': 9, 'green': 5, 'blue': 1}
# Cycle end
# Ex
# Ex
# newmin: {'red': 9, 'green': 5, 'blue': 1}
# Cycle end
# key1 : red
# j[key]: 11, min[key]: 0
# min[key]: 11
# key1 : green
# j[key]: 19, min[key]: 0
# min[key]: 19
# key1 : blue
# j[key]: 3, min[key]: 0
# min[key]: 3
# newmin: {'red': 11, 'green': 19, 'blue': 3}
# Cycle end
# key1 : red
# j[key]: 13, min[key]: 11
# min[key]: 13
# key1 : blue
# j[key]: 5, min[key]: 3
# min[key]: 5
# newmin: {'red': 13, 'green': 19, 'blue': 5}
# Cycle end
# key1 : red
# j[key]: 16, min[key]: 13
# min[key]: 16
# key1 : blue
# j[key]: 8, min[key]: 5
# min[key]: 8
# newmin: {'red': 16, 'green': 19, 'blue': 8}
# Cycle end
# newmin: {'red': 16, 'green': 19, 'blue': 8}
# Cycle end
# newmin: {'red': 16, 'green': 19, 'blue': 8}
# Cycle end
# newmin: {'red': 16, 'green': 19, 'blue': 8}
# Cycle end
# key1 : red
# j[key]: 12, min[key]: 0
# min[key]: 12
# key1 : green
# j[key]: 1, min[key]: 0
# min[key]: 1
# key1 : blue
# j[key]: 15, min[key]: 0
# min[key]: 15
# newmin: {'red': 12, 'green': 1, 'blue': 15}
# Cycle end
# key1 : green
# j[key]: 3, min[key]: 1
# min[key]: 3
# newmin: {'red': 12, 'green': 3, 'blue': 15}
# Cycle end
# key1 : red
# j[key]: 17, min[key]: 12
# min[key]: 17
# key1 : green
# j[key]: 4, min[key]: 3
# min[key]: 4
# newmin: {'red': 17, 'green': 4, 'blue': 15}
# Cycle end
# Ex
# newmin: {'red': 17, 'green': 4, 'blue': 15}
# Cycle end
# newmin: {'red': 17, 'green': 4, 'blue': 15}
# Cycle end
# Ex
# newmin: {'red': 17, 'green': 4, 'blue': 15}
# Cycle end
# key1 : red
# j[key]: 3, min[key]: 0
# min[key]: 3
# key1 : green
# j[key]: 2, min[key]: 0
# min[key]: 2
# key1 : blue
# j[key]: 2, min[key]: 0
# min[key]: 2
# newmin: {'red': 3, 'green': 2, 'blue': 2}
# Cycle end
# key1 : red
# j[key]: 4, min[key]: 3
# min[key]: 4
# Ex
# newmin: {'red': 4, 'green': 2, 'blue': 2}
# Cycle end
# Ex
# newmin: {'red': 4, 'green': 2, 'blue': 2}
# Cycle end
# newmin: {'red': 4, 'green': 2, 'blue': 2}
# Cycle end
# key1 : red
# j[key]: 4, min[key]: 0
# min[key]: 4
# key1 : green
# j[key]: 3, min[key]: 0
# min[key]: 3
# key1 : blue
# j[key]: 5, min[key]: 0
# min[key]: 5
# newmin: {'red': 4, 'green': 3, 'blue': 5}
# Cycle end
# Ex
# newmin: {'red': 4, 'green': 3, 'blue': 5}
# Cycle end
# newmin: {'red': 4, 'green': 3, 'blue': 5}
# Cycle end
# key1 : red
# j[key]: 8, min[key]: 4
# min[key]: 8
# Ex
# key1 : blue
# j[key]: 8, min[key]: 5
# min[key]: 8
# newmin: {'red': 8, 'green': 3, 'blue': 8}
# Cycle end
# Ex
# Ex
# newmin: {'red': 8, 'green': 3, 'blue': 8}
# Cycle end
# newmin: {'red': 8, 'green': 3, 'blue': 8}
# Cycle end
# key1 : red
# j[key]: 2, min[key]: 0
# min[key]: 2
# key1 : green
# j[key]: 12, min[key]: 0
# min[key]: 12
# key1 : blue
# j[key]: 3, min[key]: 0
# min[key]: 3
# newmin: {'red': 2, 'green': 12, 'blue': 3}
# Cycle end
# key1 : red
# j[key]: 13, min[key]: 2
# min[key]: 13
# key1 : blue
# j[key]: 4, min[key]: 3
# min[key]: 4
# newmin: {'red': 13, 'green': 12, 'blue': 4}
# Cycle end
# Ex
# newmin: {'red': 13, 'green': 12, 'blue': 4}
# Cycle end
# Ex
# Ex
# newmin: {'red': 13, 'green': 12, 'blue': 4}
# Cycle end
# Ex
# newmin: {'red': 13, 'green': 12, 'blue': 4}
# Cycle end
# key1 : red
# j[key]: 15, min[key]: 13
# min[key]: 15
# newmin: {'red': 15, 'green': 12, 'blue': 4}
# Cycle end
# Ex
# key1 : green
# j[key]: 1, min[key]: 0
# min[key]: 1
# key1 : blue
# j[key]: 8, min[key]: 0
# min[key]: 8
# newmin: {'red': 0, 'green': 1, 'blue': 8}
# Cycle end
# key1 : red
# j[key]: 3, min[key]: 0
# min[key]: 3
# key1 : green
# j[key]: 7, min[key]: 1
# min[key]: 7
# Ex
# newmin: {'red': 3, 'green': 7, 'blue': 8}
# Cycle end
# key1 : red
# j[key]: 4, min[key]: 3
# min[key]: 4
# Ex
# newmin: {'red': 4, 'green': 7, 'blue': 8}
# Cycle end
# key1 : red
# j[key]: 5, min[key]: 4
# min[key]: 5
# key1 : green
# j[key]: 9, min[key]: 7
# min[key]: 9
# Ex
# newmin: {'red': 5, 'green': 9, 'blue': 8}
# Cycle end
# key1 : red
# j[key]: 3, min[key]: 0
# min[key]: 3
# key1 : green
# j[key]: 2, min[key]: 0
# min[key]: 2
# key1 : blue
# j[key]: 12, min[key]: 0
# min[key]: 12
# newmin: {'red': 3, 'green': 2, 'blue': 12}
# Cycle end
# key1 : green
# j[key]: 12, min[key]: 2
# min[key]: 12
# newmin: {'red': 3, 'green': 12, 'blue': 12}
# Cycle end
# Ex
# newmin: {'red': 3, 'green': 12, 'blue': 12}
# Cycle end
# newmin: {'red': 3, 'green': 12, 'blue': 12}
# Cycle end
# key1 : red
# j[key]: 4, min[key]: 0
# min[key]: 4
# key1 : green
# j[key]: 6, min[key]: 0
# min[key]: 6
# key1 : blue
# j[key]: 4, min[key]: 0
# min[key]: 4
# newmin: {'red': 4, 'green': 6, 'blue': 4}
# Cycle end
# key1 : green
# j[key]: 8, min[key]: 6
# min[key]: 8
# newmin: {'red': 4, 'green': 8, 'blue': 4}
# Cycle end
# newmin: {'red': 4, 'green': 8, 'blue': 4}
# Cycle end
# key1 : red
# j[key]: 4, min[key]: 0
# min[key]: 4
# key1 : green
# j[key]: 5, min[key]: 0
# min[key]: 5
# key1 : blue
# j[key]: 12, min[key]: 0
# min[key]: 12
# newmin: {'red': 4, 'green': 5, 'blue': 12}
# Cycle end
# key1 : blue
# j[key]: 18, min[key]: 12
# min[key]: 18
# newmin: {'red': 4, 'green': 5, 'blue': 18}
# Cycle end
# Ex
# newmin: {'red': 4, 'green': 5, 'blue': 18}
# Cycle end
# key1 : green
# j[key]: 9, min[key]: 5
# min[key]: 9
# newmin: {'red': 4, 'green': 9, 'blue': 18}
# Cycle end
# newmin: {'red': 4, 'green': 9, 'blue': 18}
# Cycle end
# key1 : red
# j[key]: 8, min[key]: 0
# min[key]: 8
# Ex
# key1 : blue
# j[key]: 3, min[key]: 0
# min[key]: 3
# newmin: {'red': 8, 'green': 0, 'blue': 3}
# Cycle end
# Ex
# key1 : blue
# j[key]: 6, min[key]: 3
# min[key]: 6
# newmin: {'red': 8, 'green': 0, 'blue': 6}
# Cycle end
# key1 : red
# j[key]: 9, min[key]: 8
# min[key]: 9
# key1 : green
# j[key]: 3, min[key]: 0
# min[key]: 3
# key1 : blue
# j[key]: 10, min[key]: 6
# min[key]: 10
# newmin: {'red': 9, 'green': 3, 'blue': 10}
# Cycle end
# key1 : red
# j[key]: 10, min[key]: 9
# min[key]: 10
# key1 : green
# j[key]: 4, min[key]: 3
# min[key]: 4
# Ex
# newmin: {'red': 10, 'green': 4, 'blue': 10}
# Cycle end
# key1 : red
# j[key]: 7, min[key]: 0
# min[key]: 7
# key1 : green
# j[key]: 1, min[key]: 0
# min[key]: 1
# key1 : blue
# j[key]: 3, min[key]: 0
# min[key]: 3
# newmin: {'red': 7, 'green': 1, 'blue': 3}
# Cycle end
# key1 : red
# j[key]: 9, min[key]: 7
# min[key]: 9
# key1 : green
# j[key]: 6, min[key]: 1
# min[key]: 6
# key1 : blue
# j[key]: 6, min[key]: 3
# min[key]: 6
# newmin: {'red': 9, 'green': 6, 'blue': 6}
# Cycle end
# Ex
# Ex
# newmin: {'red': 9, 'green': 6, 'blue': 6}
# Cycle end
# key1 : red
# j[key]: 7, min[key]: 0
# min[key]: 7
# key1 : green
# j[key]: 1, min[key]: 0
# min[key]: 1
# key1 : blue
# j[key]: 1, min[key]: 0
# min[key]: 1
# newmin: {'red': 7, 'green': 1, 'blue': 1}
# Cycle end
# key1 : green
# j[key]: 3, min[key]: 1
# min[key]: 3
# key1 : blue
# j[key]: 2, min[key]: 1
# min[key]: 2
# newmin: {'red': 7, 'green': 3, 'blue': 2}
# Cycle end
# key1 : red
# j[key]: 9, min[key]: 7
# min[key]: 9
# Ex
# key1 : blue
# j[key]: 9, min[key]: 2
# min[key]: 9
# newmin: {'red': 9, 'green': 3, 'blue': 9}
# Cycle end
# newmin: {'red': 9, 'green': 3, 'blue': 9}
# Cycle end
# newmin: {'red': 9, 'green': 3, 'blue': 9}
# Cycle end
# key1 : red
# j[key]: 3, min[key]: 0
# min[key]: 3
# key1 : green
# j[key]: 1, min[key]: 0
# min[key]: 1
# key1 : blue
# j[key]: 1, min[key]: 0
# min[key]: 1
# newmin: {'red': 3, 'green': 1, 'blue': 1}
# Cycle end
# key1 : green
# j[key]: 2, min[key]: 1
# min[key]: 2
# key1 : blue
# j[key]: 2, min[key]: 1
# min[key]: 2
# newmin: {'red': 3, 'green': 2, 'blue': 2}
# Cycle end
# key1 : red
# j[key]: 5, min[key]: 3
# min[key]: 5
# key1 : green
# j[key]: 8, min[key]: 2
# min[key]: 8
# newmin: {'red': 5, 'green': 8, 'blue': 2}
# Cycle end
# newmin: {'red': 5, 'green': 8, 'blue': 2}
# Cycle end
# key1 : red
# j[key]: 13, min[key]: 5
# min[key]: 13
# Ex
# newmin: {'red': 13, 'green': 8, 'blue': 2}
# Cycle end
# key1 : red
# j[key]: 5, min[key]: 0
# min[key]: 5
# key1 : green
# j[key]: 3, min[key]: 0
# min[key]: 3
# key1 : blue
# j[key]: 17, min[key]: 0
# min[key]: 17
# newmin: {'red': 5, 'green': 3, 'blue': 17}
# Cycle end
# key1 : green
# j[key]: 10, min[key]: 3
# min[key]: 10
# newmin: {'red': 5, 'green': 10, 'blue': 17}
# Cycle end
# newmin: {'red': 5, 'green': 10, 'blue': 17}
# Cycle end
# key1 : red
# j[key]: 10, min[key]: 5
# min[key]: 10
# newmin: {'red': 10, 'green': 10, 'blue': 17}
# Cycle end
# key1 : red
# j[key]: 7, min[key]: 0
# min[key]: 7
# key1 : green
# j[key]: 2, min[key]: 0
# min[key]: 2
# key1 : blue
# j[key]: 8, min[key]: 0
# min[key]: 8
# newmin: {'red': 7, 'green': 2, 'blue': 8}
# Cycle end
# Ex
# newmin: {'red': 7, 'green': 2, 'blue': 8}
# Cycle end
# key1 : red
# j[key]: 9, min[key]: 7
# min[key]: 9
# newmin: {'red': 9, 'green': 2, 'blue': 8}
# Cycle end
# Ex
# newmin: {'red': 9, 'green': 2, 'blue': 8}
# Cycle end
# key1 : blue
# j[key]: 9, min[key]: 8
# min[key]: 9
# newmin: {'red': 9, 'green': 2, 'blue': 9}
# Cycle end
# Ex
# newmin: {'red': 9, 'green': 2, 'blue': 9}
# Cycle end
# key1 : red
# j[key]: 14, min[key]: 0
# min[key]: 14
# key1 : green
# j[key]: 1, min[key]: 0
# min[key]: 1
# key1 : blue
# j[key]: 6, min[key]: 0
# min[key]: 6
# newmin: {'red': 14, 'green': 1, 'blue': 6}
# Cycle end
# key1 : green
# j[key]: 7, min[key]: 1
# min[key]: 7
# newmin: {'red': 14, 'green': 7, 'blue': 6}
# Cycle end
# key1 : red
# j[key]: 16, min[key]: 14
# min[key]: 16
# key1 : blue
# j[key]: 7, min[key]: 6
# min[key]: 7
# newmin: {'red': 16, 'green': 7, 'blue': 7}
# Cycle end
# key1 : red
# j[key]: 5, min[key]: 0
# min[key]: 5
# Ex
# key1 : blue
# j[key]: 5, min[key]: 0
# min[key]: 5
# newmin: {'red': 5, 'green': 0, 'blue': 5}
# Cycle end
# key1 : red
# j[key]: 8, min[key]: 5
# min[key]: 8
# key1 : green
# j[key]: 1, min[key]: 0
# min[key]: 1
# key1 : blue
# j[key]: 9, min[key]: 5
# min[key]: 9
# newmin: {'red': 8, 'green': 1, 'blue': 9}
# Cycle end
# Ex
# newmin: {'red': 8, 'green': 1, 'blue': 9}
# Cycle end
# key1 : red
# j[key]: 17, min[key]: 0
# min[key]: 17
# key1 : green
# j[key]: 4, min[key]: 0
# min[key]: 4
# key1 : blue
# j[key]: 14, min[key]: 0
# min[key]: 14
# newmin: {'red': 17, 'green': 4, 'blue': 14}
# Cycle end
# newmin: {'red': 17, 'green': 4, 'blue': 14}
# Cycle end
# newmin: {'red': 17, 'green': 4, 'blue': 14}
# Cycle end
# key1 : red
# j[key]: 10, min[key]: 0
# min[key]: 10
# key1 : green
# j[key]: 7, min[key]: 0
# min[key]: 7
# key1 : blue
# j[key]: 1, min[key]: 0
# min[key]: 1
# newmin: {'red': 10, 'green': 7, 'blue': 1}
# Cycle end
# Ex
# key1 : blue
# j[key]: 4, min[key]: 1
# min[key]: 4
# newmin: {'red': 10, 'green': 7, 'blue': 4}
# Cycle end
# newmin: {'red': 10, 'green': 7, 'blue': 4}
# Cycle end
# key1 : red
# j[key]: 8, min[key]: 0
# min[key]: 8
# key1 : green
# j[key]: 2, min[key]: 0
# min[key]: 2
# key1 : blue
# j[key]: 13, min[key]: 0
# min[key]: 13
# newmin: {'red': 8, 'green': 2, 'blue': 13}
# Cycle end
# key1 : red
# j[key]: 10, min[key]: 8
# min[key]: 10
# Ex
# newmin: {'red': 10, 'green': 2, 'blue': 13}
# Cycle end
# key1 : green
# j[key]: 4, min[key]: 2
# min[key]: 4
# key1 : blue
# j[key]: 15, min[key]: 13
# min[key]: 15
# newmin: {'red': 10, 'green': 4, 'blue': 15}
# Cycle end
# key1 : red
# j[key]: 16, min[key]: 10
# min[key]: 16
# newmin: {'red': 16, 'green': 4, 'blue': 15}
# Cycle end
# key1 : red
# j[key]: 9, min[key]: 0
# min[key]: 9
# key1 : green
# j[key]: 8, min[key]: 0
# min[key]: 8
# key1 : blue
# j[key]: 1, min[key]: 0
# min[key]: 1
# newmin: {'red': 9, 'green': 8, 'blue': 1}
# Cycle end
# key1 : green
# j[key]: 10, min[key]: 8
# min[key]: 10
# Ex
# newmin: {'red': 9, 'green': 10, 'blue': 1}
# Cycle end
# newmin: {'red': 9, 'green': 10, 'blue': 1}
# Cycle end
# Ex
# newmin: {'red': 9, 'green': 10, 'blue': 1}
# Cycle end
# key1 : red
# j[key]: 1, min[key]: 0
# min[key]: 1
# key1 : green
# j[key]: 18, min[key]: 0
# min[key]: 18
# key1 : blue
# j[key]: 11, min[key]: 0
# min[key]: 11
# newmin: {'red': 1, 'green': 18, 'blue': 11}
# Cycle end
# key1 : red
# j[key]: 13, min[key]: 1
# min[key]: 13
# Ex
# newmin: {'red': 13, 'green': 18, 'blue': 11}
# Cycle end
# key1 : red
# j[key]: 18, min[key]: 13
# min[key]: 18
# newmin: {'red': 18, 'green': 18, 'blue': 11}
# Cycle end
# key1 : red
# j[key]: 10, min[key]: 0
# min[key]: 10
# key1 : green
# j[key]: 2, min[key]: 0
# min[key]: 2
# key1 : blue
# j[key]: 6, min[key]: 0
# min[key]: 6
# newmin: {'red': 10, 'green': 2, 'blue': 6}
# Cycle end
# key1 : green
# j[key]: 7, min[key]: 2
# min[key]: 7
# newmin: {'red': 10, 'green': 7, 'blue': 6}
# Cycle end
# newmin: {'red': 10, 'green': 7, 'blue': 6}
# Cycle end
# newmin: {'red': 10, 'green': 7, 'blue': 6}
# Cycle end
# key1 : red
# j[key]: 7, min[key]: 0
# min[key]: 7
# key1 : green
# j[key]: 9, min[key]: 0
# min[key]: 9
# key1 : blue
# j[key]: 1, min[key]: 0
# min[key]: 1
# newmin: {'red': 7, 'green': 9, 'blue': 1}
# Cycle end
# key1 : red
# j[key]: 11, min[key]: 7
# min[key]: 11
# key1 : green
# j[key]: 10, min[key]: 9
# min[key]: 10
# key1 : blue
# j[key]: 2, min[key]: 1
# min[key]: 2
# newmin: {'red': 11, 'green': 10, 'blue': 2}
# Cycle end
# key1 : red
# j[key]: 12, min[key]: 11
# min[key]: 12
# newmin: {'red': 12, 'green': 10, 'blue': 2}
# Cycle end
# key1 : blue
# j[key]: 3, min[key]: 2
# min[key]: 3
# newmin: {'red': 12, 'green': 10, 'blue': 3}
# Cycle end
# key1 : red
# j[key]: 14, min[key]: 12
# min[key]: 14
# newmin: {'red': 14, 'green': 10, 'blue': 3}
# Cycle end
# Ex
# key1 : green
# j[key]: 4, min[key]: 0
# min[key]: 4
# Ex
# newmin: {'red': 0, 'green': 4, 'blue': 0}
# Cycle end
# Ex
# Ex
# key1 : blue
# j[key]: 6, min[key]: 0
# min[key]: 6
# newmin: {'red': 0, 'green': 4, 'blue': 6}
# Cycle end
# Ex
# key1 : blue
# j[key]: 7, min[key]: 6
# min[key]: 7
# newmin: {'red': 0, 'green': 4, 'blue': 7}
# Cycle end
# Ex
# Ex
# newmin: {'red': 0, 'green': 4, 'blue': 7}
# Cycle end
# key1 : red
# j[key]: 1, min[key]: 0
# min[key]: 1
# key1 : green
# j[key]: 8, min[key]: 4
# min[key]: 8
# newmin: {'red': 1, 'green': 8, 'blue': 7}
# Cycle end
# key1 : red
# j[key]: 13, min[key]: 0
# min[key]: 13
# key1 : green
# j[key]: 6, min[key]: 0
# min[key]: 6
# key1 : blue
# j[key]: 3, min[key]: 0
# min[key]: 3
# newmin: {'red': 13, 'green': 6, 'blue': 3}
# Cycle end
# key1 : red
# j[key]: 16, min[key]: 13
# min[key]: 16
# newmin: {'red': 16, 'green': 6, 'blue': 3}
# Cycle end
# key1 : green
# j[key]: 9, min[key]: 6
# min[key]: 9
# newmin: {'red': 16, 'green': 9, 'blue': 3}
# Cycle end
# newmin: {'red': 16, 'green': 9, 'blue': 3}
# Cycle end
# key1 : red
# j[key]: 10, min[key]: 0
# min[key]: 10
# key1 : green
# j[key]: 1, min[key]: 0
# min[key]: 1
# key1 : blue
# j[key]: 4, min[key]: 0
# min[key]: 4
# newmin: {'red': 10, 'green': 1, 'blue': 4}
# Cycle end
# Ex
# key1 : blue
# j[key]: 6, min[key]: 4
# min[key]: 6
# newmin: {'red': 10, 'green': 1, 'blue': 6}
# Cycle end
# Ex
# newmin: {'red': 10, 'green': 1, 'blue': 6}
# Cycle end
# newmin: {'red': 10, 'green': 1, 'blue': 6}
# Cycle end
# key1 : red
# j[key]: 17, min[key]: 0
# min[key]: 17
# Ex
# Ex
# newmin: {'red': 17, 'green': 0, 'blue': 0}
# Cycle end
# key1 : red
# j[key]: 18, min[key]: 17
# min[key]: 18
# key1 : green
# j[key]: 4, min[key]: 0
# min[key]: 4
# key1 : blue
# j[key]: 3, min[key]: 0
# min[key]: 3
# newmin: {'red': 18, 'green': 4, 'blue': 3}
# Cycle end
# key1 : blue
# j[key]: 5, min[key]: 3
# min[key]: 5
# newmin: {'red': 18, 'green': 4, 'blue': 5}
# Cycle end
# newmin: {'red': 18, 'green': 4, 'blue': 5}
# Cycle end
# Ex
# newmin: {'red': 18, 'green': 4, 'blue': 5}
# Cycle end
# key1 : red
# j[key]: 2, min[key]: 0
# min[key]: 2
# key1 : green
# j[key]: 14, min[key]: 0
# min[key]: 14
# key1 : blue
# j[key]: 18, min[key]: 0
# min[key]: 18
# newmin: {'red': 2, 'green': 14, 'blue': 18}
# Cycle end
# newmin: {'red': 2, 'green': 14, 'blue': 18}
# Cycle end
# newmin: {'red': 2, 'green': 14, 'blue': 18}
# Cycle end
# key1 : red
# j[key]: 12, min[key]: 0
# min[key]: 12
# key1 : green
# j[key]: 2, min[key]: 0
# min[key]: 2
# key1 : blue
# j[key]: 4, min[key]: 0
# min[key]: 4
# newmin: {'red': 12, 'green': 2, 'blue': 4}
# Cycle end
# newmin: {'red': 12, 'green': 2, 'blue': 4}
# Cycle end
# key1 : green
# j[key]: 4, min[key]: 2
# min[key]: 4
# newmin: {'red': 12, 'green': 4, 'blue': 4}
# Cycle end
# Ex
# newmin: {'red': 12, 'green': 4, 'blue': 4}
# Cycle end
# newmin: {'red': 12, 'green': 4, 'blue': 4}
# Cycle end
# key1 : red
# j[key]: 5, min[key]: 0
# min[key]: 5
# key1 : green
# j[key]: 2, min[key]: 0
# min[key]: 2
# key1 : blue
# j[key]: 2, min[key]: 0
# min[key]: 2
# newmin: {'red': 5, 'green': 2, 'blue': 2}
# Cycle end
# key1 : red
# j[key]: 6, min[key]: 5
# min[key]: 6
# key1 : green
# j[key]: 6, min[key]: 2
# min[key]: 6
# Ex
# newmin: {'red': 6, 'green': 6, 'blue': 2}
# Cycle end
# key1 : red
# j[key]: 8, min[key]: 6
# min[key]: 8
# key1 : green
# j[key]: 11, min[key]: 6
# min[key]: 11
# newmin: {'red': 8, 'green': 11, 'blue': 2}
# Cycle end
# key1 : red
# j[key]: 11, min[key]: 8
# min[key]: 11
# newmin: {'red': 11, 'green': 11, 'blue': 2}
# Cycle end
# key1 : green
# j[key]: 17, min[key]: 11
# min[key]: 17
# newmin: {'red': 11, 'green': 17, 'blue': 2}
# Cycle end
# newmin: {'red': 11, 'green': 17, 'blue': 2}
# Cycle end
# key1 : red
# j[key]: 1, min[key]: 0
# min[key]: 1
# key1 : green
# j[key]: 16, min[key]: 0
# min[key]: 16
# key1 : blue
# j[key]: 4, min[key]: 0
# min[key]: 4
# newmin: {'red': 1, 'green': 16, 'blue': 4}
# Cycle end
# newmin: {'red': 1, 'green': 16, 'blue': 4}
# Cycle end
# Ex
# key1 : blue
# j[key]: 6, min[key]: 4
# min[key]: 6
# newmin: {'red': 1, 'green': 16, 'blue': 6}
# Cycle end
# Ex
# newmin: {'red': 1, 'green': 16, 'blue': 6}
# Cycle end
# Ex
# newmin: {'red': 1, 'green': 16, 'blue': 6}
# Cycle end
# Ex
# newmin: {'red': 1, 'green': 16, 'blue': 6}
# Cycle end
# key1 : red
# j[key]: 4, min[key]: 0
# min[key]: 4
# key1 : green
# j[key]: 5, min[key]: 0
# min[key]: 5
# key1 : blue
# j[key]: 1, min[key]: 0
# min[key]: 1
# newmin: {'red': 4, 'green': 5, 'blue': 1}
# Cycle end
# Ex
# key1 : blue
# j[key]: 6, min[key]: 1
# min[key]: 6
# newmin: {'red': 4, 'green': 5, 'blue': 6}
# Cycle end
# key1 : green
# j[key]: 17, min[key]: 5
# min[key]: 17
# Ex
# newmin: {'red': 4, 'green': 17, 'blue': 6}
# Cycle end
# key1 : blue
# j[key]: 11, min[key]: 6
# min[key]: 11
# newmin: {'red': 4, 'green': 17, 'blue': 11}
# Cycle end
# newmin: {'red': 4, 'green': 17, 'blue': 11}
# Cycle end
# key1 : red
# j[key]: 6, min[key]: 0
# min[key]: 6
# key1 : green
# j[key]: 1, min[key]: 0
# min[key]: 1
# key1 : blue
# j[key]: 7, min[key]: 0
# min[key]: 7
# newmin: {'red': 6, 'green': 1, 'blue': 7}
# Cycle end
# key1 : green
# j[key]: 10, min[key]: 1
# min[key]: 10
# key1 : blue
# j[key]: 16, min[key]: 7
# min[key]: 16
# newmin: {'red': 6, 'green': 10, 'blue': 16}
# Cycle end
# key1 : red
# j[key]: 7, min[key]: 6
# min[key]: 7
# newmin: {'red': 7, 'green': 10, 'blue': 16}
# Cycle end
# key1 : red
# j[key]: 12, min[key]: 7
# min[key]: 12
# newmin: {'red': 12, 'green': 10, 'blue': 16}
# Cycle end
# Ex
# newmin: {'red': 12, 'green': 10, 'blue': 16}
# Cycle end
# key1 : red
# j[key]: 4, min[key]: 0
# min[key]: 4
# Ex
# key1 : blue
# j[key]: 9, min[key]: 0
# min[key]: 9
# newmin: {'red': 4, 'green': 0, 'blue': 9}
# Cycle end
# key1 : green
# j[key]: 1, min[key]: 0
# min[key]: 1
# newmin: {'red': 4, 'green': 1, 'blue': 9}
# Cycle end
# key1 : red
# j[key]: 8, min[key]: 4
# min[key]: 8
# Ex
# newmin: {'red': 8, 'green': 1, 'blue': 9}
# Cycle end
# Ex
# key1 : blue
# j[key]: 15, min[key]: 9
# min[key]: 15
# newmin: {'red': 8, 'green': 1, 'blue': 15}
# Cycle end
# key1 : red
# j[key]: 10, min[key]: 8
# min[key]: 10
# Ex
# newmin: {'red': 10, 'green': 1, 'blue': 15}
# Cycle end
# key1 : red
# j[key]: 2, min[key]: 0
# min[key]: 2
# key1 : green
# j[key]: 8, min[key]: 0
# min[key]: 8
# key1 : blue
# j[key]: 4, min[key]: 0
# min[key]: 4
# newmin: {'red': 2, 'green': 8, 'blue': 4}
# Cycle end
# newmin: {'red': 2, 'green': 8, 'blue': 4}
# Cycle end
# Ex
# newmin: {'red': 2, 'green': 8, 'blue': 4}
# Cycle end
# Ex
# key1 : green
# j[key]: 9, min[key]: 8
# min[key]: 9
# newmin: {'red': 2, 'green': 9, 'blue': 4}
# Cycle end
# key1 : red
# j[key]: 13, min[key]: 0
# min[key]: 13
# key1 : green
# j[key]: 4, min[key]: 0
# min[key]: 4
# Ex
# newmin: {'red': 13, 'green': 4, 'blue': 0}
# Cycle end
# key1 : green
# j[key]: 6, min[key]: 4
# min[key]: 6
# key1 : blue
# j[key]: 2, min[key]: 0
# min[key]: 2
# newmin: {'red': 13, 'green': 6, 'blue': 2}
# Cycle end
# newmin: {'red': 13, 'green': 6, 'blue': 2}
# Cycle end
# Ex
# newmin: {'red': 13, 'green': 6, 'blue': 2}
# Cycle end
# key1 : green
# j[key]: 9, min[key]: 6
# min[key]: 9
# Ex
# newmin: {'red': 13, 'green': 9, 'blue': 2}
# Cycle end
# key1 : green
# j[key]: 10, min[key]: 9
# min[key]: 10
# newmin: {'red': 13, 'green': 10, 'blue': 2}
# Cycle end
# key1 : red
# j[key]: 3, min[key]: 0
# min[key]: 3
# key1 : green
# j[key]: 3, min[key]: 0
# min[key]: 3
# key1 : blue
# j[key]: 8, min[key]: 0
# min[key]: 8
# newmin: {'red': 3, 'green': 3, 'blue': 8}
# Cycle end
# key1 : red
# j[key]: 6, min[key]: 3
# min[key]: 6
# key1 : green
# j[key]: 8, min[key]: 3
# min[key]: 8
# Ex
# newmin: {'red': 6, 'green': 8, 'blue': 8}
# Cycle end
# key1 : red
# j[key]: 7, min[key]: 6
# min[key]: 7
# newmin: {'red': 7, 'green': 8, 'blue': 8}
# Cycle end
# key1 : red
# j[key]: 6, min[key]: 0
# min[key]: 6
# key1 : green
# j[key]: 2, min[key]: 0
# min[key]: 2
# key1 : blue
# j[key]: 2, min[key]: 0
# min[key]: 2
# newmin: {'red': 6, 'green': 2, 'blue': 2}
# Cycle end
# key1 : red
# j[key]: 11, min[key]: 6
# min[key]: 11
# key1 : green
# j[key]: 15, min[key]: 2
# min[key]: 15
# newmin: {'red': 11, 'green': 15, 'blue': 2}
# Cycle end
# newmin: {'red': 11, 'green': 15, 'blue': 2}
# Cycle end
# Ex
# key1 : green
# j[key]: 17, min[key]: 15
# min[key]: 17
# newmin: {'red': 11, 'green': 17, 'blue': 2}
# Cycle end
# newmin: {'red': 11, 'green': 17, 'blue': 2}
# Cycle end
# key1 : blue
# j[key]: 3, min[key]: 2
# min[key]: 3
# newmin: {'red': 11, 'green': 17, 'blue': 3}
# Cycle end
# key1 : red
# j[key]: 2, min[key]: 0
# min[key]: 2
# key1 : green
# j[key]: 1, min[key]: 0
# min[key]: 1
# key1 : blue
# j[key]: 12, min[key]: 0
# min[key]: 12
# newmin: {'red': 2, 'green': 1, 'blue': 12}
# Cycle end
# key1 : green
# j[key]: 3, min[key]: 1
# min[key]: 3
# newmin: {'red': 2, 'green': 3, 'blue': 12}
# Cycle end
# key1 : green
# j[key]: 4, min[key]: 3
# min[key]: 4
# newmin: {'red': 2, 'green': 4, 'blue': 12}
# Cycle end
# newmin: {'red': 2, 'green': 4, 'blue': 12}
# Cycle end
# Ex
# newmin: {'red': 2, 'green': 4, 'blue': 12}
# Cycle end
# key1 : red
# j[key]: 6, min[key]: 0
# min[key]: 6
# key1 : green
# j[key]: 4, min[key]: 0
# min[key]: 4
# key1 : blue
# j[key]: 16, min[key]: 0
# min[key]: 16
# newmin: {'red': 6, 'green': 4, 'blue': 16}
# Cycle end
# key1 : red
# j[key]: 9, min[key]: 6
# min[key]: 9
# key1 : green
# j[key]: 7, min[key]: 4
# min[key]: 7
# newmin: {'red': 9, 'green': 7, 'blue': 16}
# Cycle end
# key1 : red
# j[key]: 15, min[key]: 9
# min[key]: 15
# key1 : green
# j[key]: 16, min[key]: 7
# min[key]: 16
# newmin: {'red': 15, 'green': 16, 'blue': 16}
# Cycle end
# Ex
# newmin: {'red': 15, 'green': 16, 'blue': 16}
# Cycle end
# key1 : red
# j[key]: 16, min[key]: 15
# min[key]: 16
# Ex
# Ex
# newmin: {'red': 16, 'green': 16, 'blue': 16}
# Cycle end
# newmin: {'red': 16, 'green': 16, 'blue': 16}
# Cycle end
# key1 : red
# j[key]: 14, min[key]: 0
# min[key]: 14
# key1 : green
# j[key]: 14, min[key]: 0
# min[key]: 14
# key1 : blue
# j[key]: 3, min[key]: 0
# min[key]: 3
# newmin: {'red': 14, 'green': 14, 'blue': 3}
# Cycle end
# key1 : green
# j[key]: 18, min[key]: 14
# min[key]: 18
# key1 : blue
# j[key]: 4, min[key]: 3
# min[key]: 4
# newmin: {'red': 14, 'green': 18, 'blue': 4}
# Cycle end
# key1 : blue
# j[key]: 9, min[key]: 4
# min[key]: 9
# newmin: {'red': 14, 'green': 18, 'blue': 9}
# Cycle end
# newmin: {'red': 14, 'green': 18, 'blue': 9}
# Cycle end
# key1 : red
# j[key]: 5, min[key]: 0
# min[key]: 5
# key1 : green
# j[key]: 2, min[key]: 0
# min[key]: 2
# key1 : blue
# j[key]: 12, min[key]: 0
# min[key]: 12
# newmin: {'red': 5, 'green': 2, 'blue': 12}
# Cycle end
# key1 : green
# j[key]: 3, min[key]: 2
# min[key]: 3
# newmin: {'red': 5, 'green': 3, 'blue': 12}
# Cycle end
# Ex
# newmin: {'red': 5, 'green': 3, 'blue': 12}
# Cycle end
# key1 : red
# j[key]: 6, min[key]: 5
# min[key]: 6
# Ex
# newmin: {'red': 6, 'green': 3, 'blue': 12}
# Cycle end
# Ex
# newmin: {'red': 6, 'green': 3, 'blue': 12}
# Cycle end
# newmin: {'red': 6, 'green': 3, 'blue': 12}
# Cycle end
# key1 : red
# j[key]: 3, min[key]: 0
# min[key]: 3
# key1 : green
# j[key]: 3, min[key]: 0
# min[key]: 3
# Ex
# newmin: {'red': 3, 'green': 3, 'blue': 0}
# Cycle end
# key1 : green
# j[key]: 6, min[key]: 3
# min[key]: 6
# key1 : blue
# j[key]: 11, min[key]: 0
# min[key]: 11
# newmin: {'red': 3, 'green': 6, 'blue': 11}
# Cycle end
# key1 : red
# j[key]: 6, min[key]: 3
# min[key]: 6
# Ex
# newmin: {'red': 6, 'green': 6, 'blue': 11}
# Cycle end
# key1 : red
# j[key]: 4, min[key]: 0
# min[key]: 4
# key1 : green
# j[key]: 4, min[key]: 0
# min[key]: 4
# key1 : blue
# j[key]: 9, min[key]: 0
# min[key]: 9
# newmin: {'red': 4, 'green': 4, 'blue': 9}
# Cycle end
# key1 : red
# j[key]: 5, min[key]: 4
# min[key]: 5
# newmin: {'red': 5, 'green': 4, 'blue': 9}
# Cycle end
# key1 : green
# j[key]: 11, min[key]: 4
# min[key]: 11
# newmin: {'red': 5, 'green': 11, 'blue': 9}
# Cycle end
# key1 : red
# j[key]: 13, min[key]: 0
# min[key]: 13
# Ex
# key1 : blue
# j[key]: 1, min[key]: 0
# min[key]: 1
# newmin: {'red': 13, 'green': 0, 'blue': 1}
# Cycle end
# Ex
# Ex
# newmin: {'red': 13, 'green': 0, 'blue': 1}
# Cycle end
# key1 : green
# j[key]: 1, min[key]: 0
# min[key]: 1
# key1 : blue
# j[key]: 6, min[key]: 1
# min[key]: 6
# newmin: {'red': 13, 'green': 1, 'blue': 6}
# Cycle end
# Ex
# newmin: {'red': 13, 'green': 1, 'blue': 6}
# Cycle end
# Ex
# key1 : blue
# j[key]: 9, min[key]: 6
# min[key]: 9
# newmin: {'red': 13, 'green': 1, 'blue': 9}
# Cycle end
# key1 : red
# j[key]: 17, min[key]: 0
# min[key]: 17
# key1 : green
# j[key]: 7, min[key]: 0
# min[key]: 7
# key1 : blue
# j[key]: 3, min[key]: 0
# min[key]: 3
# newmin: {'red': 17, 'green': 7, 'blue': 3}
# Cycle end
# Ex
# newmin: {'red': 17, 'green': 7, 'blue': 3}
# Cycle end
# newmin: {'red': 17, 'green': 7, 'blue': 3}
# Cycle end
# key1 : red
# j[key]: 19, min[key]: 17
# min[key]: 19
# Ex
# newmin: {'red': 19, 'green': 7, 'blue': 3}
# Cycle end
# newmin: {'red': 19, 'green': 7, 'blue': 3}
# Cycle end
# newmin: {'red': 19, 'green': 7, 'blue': 3}
# Cycle end
# key1 : red
# j[key]: 4, min[key]: 0
# min[key]: 4
# key1 : green
# j[key]: 9, min[key]: 0
# min[key]: 9
# key1 : blue
# j[key]: 11, min[key]: 0
# min[key]: 11
# newmin: {'red': 4, 'green': 9, 'blue': 11}
# Cycle end
# key1 : blue
# j[key]: 16, min[key]: 11
# min[key]: 16
# newmin: {'red': 4, 'green': 9, 'blue': 16}
# Cycle end
# Ex
# newmin: {'red': 4, 'green': 9, 'blue': 16}
# Cycle end
# key1 : blue
# j[key]: 18, min[key]: 16
# min[key]: 18
# newmin: {'red': 4, 'green': 9, 'blue': 18}
# Cycle end
# key1 : red
# j[key]: 13, min[key]: 0
# min[key]: 13
# key1 : green
# j[key]: 5, min[key]: 0
# min[key]: 5
# key1 : blue
# j[key]: 10, min[key]: 0
# min[key]: 10
# newmin: {'red': 13, 'green': 5, 'blue': 10}
# Cycle end
# key1 : green
# j[key]: 11, min[key]: 5
# min[key]: 11
# Ex
# newmin: {'red': 13, 'green': 11, 'blue': 10}
# Cycle end
# newmin: {'red': 13, 'green': 11, 'blue': 10}
# Cycle end
# key1 : green
# j[key]: 14, min[key]: 11
# min[key]: 14
# Ex
# newmin: {'red': 13, 'green': 14, 'blue': 10}
# Cycle end
# newmin: {'red': 13, 'green': 14, 'blue': 10}
# Cycle end
# key1 : red
# j[key]: 3, min[key]: 0
# min[key]: 3
# key1 : green
# j[key]: 2, min[key]: 0
# min[key]: 2
# key1 : blue
# j[key]: 5, min[key]: 0
# min[key]: 5
# newmin: {'red': 3, 'green': 2, 'blue': 5}
# Cycle end
# Ex
# Ex
# newmin: {'red': 3, 'green': 2, 'blue': 5}
# Cycle end
# Ex
# key1 : blue
# j[key]: 6, min[key]: 5
# min[key]: 6
# newmin: {'red': 3, 'green': 2, 'blue': 6}
# Cycle end
# Ex
# newmin: {'red': 3, 'green': 2, 'blue': 6}
# Cycle end
# key1 : red
# j[key]: 9, min[key]: 0
# min[key]: 9
# key1 : green
# j[key]: 7, min[key]: 0
# min[key]: 7
# Ex
# newmin: {'red': 9, 'green': 7, 'blue': 0}
# Cycle end
# key1 : red
# j[key]: 10, min[key]: 9
# min[key]: 10
# key1 : blue
# j[key]: 2, min[key]: 0
# min[key]: 2
# newmin: {'red': 10, 'green': 7, 'blue': 2}
# Cycle end
# key1 : red
# j[key]: 13, min[key]: 10
# min[key]: 13
# key1 : green
# j[key]: 15, min[key]: 7
# min[key]: 15
# key1 : blue
# j[key]: 3, min[key]: 2
# min[key]: 3
# newmin: {'red': 13, 'green': 15, 'blue': 3}
# Cycle end
# key1 : blue
# j[key]: 9, min[key]: 3
# min[key]: 9
# newmin: {'red': 13, 'green': 15, 'blue': 9}
# Cycle end
# newmin: {'red': 13, 'green': 15, 'blue': 9}
# Cycle end
# key1 : red
# j[key]: 4, min[key]: 0
# min[key]: 4
# key1 : green
# j[key]: 3, min[key]: 0
# min[key]: 3
# Ex
# newmin: {'red': 4, 'green': 3, 'blue': 0}
# Cycle end
# key1 : green
# j[key]: 10, min[key]: 3
# min[key]: 10
# key1 : blue
# j[key]: 3, min[key]: 0
# min[key]: 3
# newmin: {'red': 4, 'green': 10, 'blue': 3}
# Cycle end
# key1 : green
# j[key]: 12, min[key]: 10
# min[key]: 12
# key1 : blue
# j[key]: 7, min[key]: 3
# min[key]: 7
# newmin: {'red': 4, 'green': 12, 'blue': 7}
# Cycle end
# key1 : red
# j[key]: 6, min[key]: 4
# min[key]: 6
# newmin: {'red': 6, 'green': 12, 'blue': 7}
# Cycle end
# newmin: {'red': 6, 'green': 12, 'blue': 7}
# Cycle end
# Ex
# newmin: {'red': 6, 'green': 12, 'blue': 7}
# Cycle end
# Ex
# key1 : green
# j[key]: 18, min[key]: 0
# min[key]: 18
# key1 : blue
# j[key]: 3, min[key]: 0
# min[key]: 3
# newmin: {'red': 0, 'green': 18, 'blue': 3}
# Cycle end
# key1 : red
# j[key]: 3, min[key]: 0
# min[key]: 3
# key1 : blue
# j[key]: 5, min[key]: 3
# min[key]: 5
# newmin: {'red': 3, 'green': 18, 'blue': 5}
# Cycle end
# key1 : red
# j[key]: 7, min[key]: 3
# min[key]: 7
# newmin: {'red': 7, 'green': 18, 'blue': 5}
# Cycle end
# newmin: {'red': 7, 'green': 18, 'blue': 5}
# Cycle end
# key1 : red
# j[key]: 10, min[key]: 0
# min[key]: 10
# key1 : green
# j[key]: 9, min[key]: 0
# min[key]: 9
# key1 : blue
# j[key]: 18, min[key]: 0
# min[key]: 18
# newmin: {'red': 10, 'green': 9, 'blue': 18}
# Cycle end
# newmin: {'red': 10, 'green': 9, 'blue': 18}
# Cycle end
# newmin: {'red': 10, 'green': 9, 'blue': 18}
# Cycle end
# key1 : red
# j[key]: 2, min[key]: 0
# min[key]: 2
# key1 : green
# j[key]: 9, min[key]: 0
# min[key]: 9
# key1 : blue
# j[key]: 2, min[key]: 0
# min[key]: 2
# newmin: {'red': 2, 'green': 9, 'blue': 2}
# Cycle end
# newmin: {'red': 2, 'green': 9, 'blue': 2}
# Cycle end
# newmin: {'red': 2, 'green': 9, 'blue': 2}
# Cycle end
# key1 : green
# j[key]: 14, min[key]: 9
# min[key]: 14
# newmin: {'red': 2, 'green': 14, 'blue': 2}
# Cycle end
# key1 : red
# j[key]: 10, min[key]: 0
# min[key]: 10
# key1 : green
# j[key]: 7, min[key]: 0
# min[key]: 7
# key1 : blue
# j[key]: 3, min[key]: 0
# min[key]: 3
# newmin: {'red': 10, 'green': 7, 'blue': 3}
# Cycle end
# key1 : red
# j[key]: 12, min[key]: 10
# min[key]: 12
# key1 : blue
# j[key]: 12, min[key]: 3
# min[key]: 12
# newmin: {'red': 12, 'green': 7, 'blue': 12}
# Cycle end
# key1 : blue
# j[key]: 13, min[key]: 12
# min[key]: 13
# newmin: {'red': 12, 'green': 7, 'blue': 13}
# Cycle end
# Ex
# key1 : green
# j[key]: 10, min[key]: 0
# min[key]: 10
# key1 : blue
# j[key]: 3, min[key]: 0
# min[key]: 3
# newmin: {'red': 0, 'green': 10, 'blue': 3}
# Cycle end
# key1 : red
# j[key]: 2, min[key]: 0
# min[key]: 2
# Ex
# newmin: {'red': 2, 'green': 10, 'blue': 3}
# Cycle end
# Ex
# newmin: {'red': 2, 'green': 10, 'blue': 3}
# Cycle end
# Ex
# newmin: {'red': 2, 'green': 10, 'blue': 3}
# Cycle end
# key1 : blue
# j[key]: 5, min[key]: 3
# min[key]: 5
# newmin: {'red': 2, 'green': 10, 'blue': 5}
# Cycle end
# newmin: {'red': 2, 'green': 10, 'blue': 5}
# Cycle end
# key1 : red
# j[key]: 5, min[key]: 0
# min[key]: 5
# key1 : green
# j[key]: 4, min[key]: 0
# min[key]: 4
# key1 : blue
# j[key]: 6, min[key]: 0
# min[key]: 6
# newmin: {'red': 5, 'green': 4, 'blue': 6}
# Cycle end
# key1 : red
# j[key]: 13, min[key]: 5
# min[key]: 13
# key1 : green
# j[key]: 11, min[key]: 4
# min[key]: 11
# newmin: {'red': 13, 'green': 11, 'blue': 6}
# Cycle end
# Ex
# newmin: {'red': 13, 'green': 11, 'blue': 6}
# Cycle end
# Ex
# newmin: {'red': 13, 'green': 11, 'blue': 6}
# Cycle end
# newmin: {'red': 13, 'green': 11, 'blue': 6}
# Cycle end
# key1 : red
# j[key]: 10, min[key]: 0
# min[key]: 10
# Ex
# key1 : blue
# j[key]: 1, min[key]: 0
# min[key]: 1
# newmin: {'red': 10, 'green': 0, 'blue': 1}
# Cycle end
# Ex
# key1 : blue
# j[key]: 2, min[key]: 1
# min[key]: 2
# newmin: {'red': 10, 'green': 0, 'blue': 2}
# Cycle end
# key1 : green
# j[key]: 2, min[key]: 0
# min[key]: 2
# newmin: {'red': 10, 'green': 2, 'blue': 2}
# Cycle end
# key1 : red
# j[key]: 13, min[key]: 0
# min[key]: 13
# key1 : green
# j[key]: 11, min[key]: 0
# min[key]: 11
# key1 : blue
# j[key]: 6, min[key]: 0
# min[key]: 6
# newmin: {'red': 13, 'green': 11, 'blue': 6}
# Cycle end
# key1 : blue
# j[key]: 8, min[key]: 6
# min[key]: 8
# newmin: {'red': 13, 'green': 11, 'blue': 8}
# Cycle end
# key1 : blue
# j[key]: 10, min[key]: 8
# min[key]: 10
# newmin: {'red': 13, 'green': 11, 'blue': 10}
# Cycle end
# key1 : green
# j[key]: 16, min[key]: 11
# min[key]: 16
# key1 : blue
# j[key]: 16, min[key]: 10
# min[key]: 16
# newmin: {'red': 13, 'green': 16, 'blue': 16}
# Cycle end
# newmin: {'red': 13, 'green': 16, 'blue': 16}
# Cycle end
# key1 : red
# j[key]: 4, min[key]: 0
# min[key]: 4
# key1 : green
# j[key]: 15, min[key]: 0
# min[key]: 15
# key1 : blue
# j[key]: 2, min[key]: 0
# min[key]: 2
# newmin: {'red': 4, 'green': 15, 'blue': 2}
# Cycle end
# key1 : red
# j[key]: 6, min[key]: 4
# min[key]: 6
# key1 : blue
# j[key]: 4, min[key]: 2
# min[key]: 4
# newmin: {'red': 6, 'green': 15, 'blue': 4}
# Cycle end
# key1 : red
# j[key]: 17, min[key]: 6
# min[key]: 17
# newmin: {'red': 17, 'green': 15, 'blue': 4}
# Cycle end
# Ex
# newmin: {'red': 17, 'green': 15, 'blue': 4}
# Cycle end
# key1 : red
# j[key]: 12, min[key]: 0
# min[key]: 12
# key1 : green
# j[key]: 6, min[key]: 0
# min[key]: 6
# key1 : blue
# j[key]: 7, min[key]: 0
# min[key]: 7
# newmin: {'red': 12, 'green': 6, 'blue': 7}
# Cycle end
# newmin: {'red': 12, 'green': 6, 'blue': 7}
# Cycle end
# key1 : red
# j[key]: 13, min[key]: 12
# min[key]: 13
# newmin: {'red': 13, 'green': 6, 'blue': 7}
# Cycle end
# key1 : green
# j[key]: 7, min[key]: 6
# min[key]: 7
# Ex
# newmin: {'red': 13, 'green': 7, 'blue': 7}
# Cycle end
# key1 : red
# j[key]: 19, min[key]: 0
# min[key]: 19
# Ex
# key1 : blue
# j[key]: 19, min[key]: 0
# min[key]: 19
# newmin: {'red': 19, 'green': 0, 'blue': 19}
# Cycle end
# key1 : green
# j[key]: 6, min[key]: 0
# min[key]: 6
# newmin: {'red': 19, 'green': 6, 'blue': 19}
# Cycle end
# newmin: {'red': 19, 'green': 6, 'blue': 19}
# Cycle end
# newmin: {'red': 19, 'green': 6, 'blue': 19}
# Cycle end
# key1 : green
# j[key]: 7, min[key]: 6
# min[key]: 7
# newmin: {'red': 19, 'green': 7, 'blue': 19}
# Cycle end
# key1 : red
# j[key]: 3, min[key]: 0
# min[key]: 3
# key1 : green
# j[key]: 1, min[key]: 0
# min[key]: 1
# Ex
# newmin: {'red': 3, 'green': 1, 'blue': 0}
# Cycle end
# key1 : red
# j[key]: 14, min[key]: 3
# min[key]: 14
# key1 : green
# j[key]: 2, min[key]: 1
# min[key]: 2
# key1 : blue
# j[key]: 2, min[key]: 0
# min[key]: 2
# newmin: {'red': 14, 'green': 2, 'blue': 2}
# Cycle end
# Ex
# key1 : blue
# j[key]: 3, min[key]: 2
# min[key]: 3
# newmin: {'red': 14, 'green': 2, 'blue': 3}
# Cycle end
# Ex
# newmin: {'red': 14, 'green': 2, 'blue': 3}
# Cycle end
# key1 : red
# j[key]: 16, min[key]: 0
# min[key]: 16
# key1 : green
# j[key]: 2, min[key]: 0
# min[key]: 2
# key1 : blue
# j[key]: 15, min[key]: 0
# min[key]: 15
# newmin: {'red': 16, 'green': 2, 'blue': 15}
# Cycle end
# key1 : green
# j[key]: 3, min[key]: 2
# min[key]: 3
# newmin: {'red': 16, 'green': 3, 'blue': 15}
# Cycle end
# Ex
# newmin: {'red': 16, 'green': 3, 'blue': 15}
# Cycle end
# Ex
# newmin: {'red': 16, 'green': 3, 'blue': 15}
# Cycle end
# key1 : red
# j[key]: 1, min[key]: 0
# min[key]: 1
# key1 : green
# j[key]: 9, min[key]: 0
# min[key]: 9
# key1 : blue
# j[key]: 1, min[key]: 0
# min[key]: 1
# newmin: {'red': 1, 'green': 9, 'blue': 1}
# Cycle end
# key1 : red
# j[key]: 3, min[key]: 1
# min[key]: 3
# key1 : green
# j[key]: 12, min[key]: 9
# min[key]: 12
# key1 : blue
# j[key]: 4, min[key]: 1
# min[key]: 4
# newmin: {'red': 3, 'green': 12, 'blue': 4}
# Cycle end
# key1 : blue
# j[key]: 7, min[key]: 4
# min[key]: 7
# newmin: {'red': 3, 'green': 12, 'blue': 7}
# Cycle end
# key1 : red
# j[key]: 5, min[key]: 0
# min[key]: 5
# key1 : green
# j[key]: 12, min[key]: 0
# min[key]: 12
# key1 : blue
# j[key]: 9, min[key]: 0
# min[key]: 9
# newmin: {'red': 5, 'green': 12, 'blue': 9}
# Cycle end
# newmin: {'red': 5, 'green': 12, 'blue': 9}
# Cycle end
# Ex
# newmin: {'red': 5, 'green': 12, 'blue': 9}
# Cycle end
# key1 : red
# j[key]: 7, min[key]: 5
# min[key]: 7
# key1 : blue
# j[key]: 10, min[key]: 9
# min[key]: 10
# newmin: {'red': 7, 'green': 12, 'blue': 10}
# Cycle end
# newmin: {'red': 7, 'green': 12, 'blue': 10}
# Cycle end
# key1 : red
# j[key]: 15, min[key]: 0
# min[key]: 15
# key1 : green
# j[key]: 10, min[key]: 0
# min[key]: 10
# key1 : blue
# j[key]: 3, min[key]: 0
# min[key]: 3
# newmin: {'red': 15, 'green': 10, 'blue': 3}
# Cycle end
# key1 : red
# j[key]: 16, min[key]: 15
# min[key]: 16
# Ex
# newmin: {'red': 16, 'green': 10, 'blue': 3}
# Cycle end
# key1 : green
# j[key]: 13, min[key]: 10
# min[key]: 13
# newmin: {'red': 16, 'green': 13, 'blue': 3}
# Cycle end
# key1 : red
# j[key]: 5, min[key]: 0
# min[key]: 5
# key1 : green
# j[key]: 2, min[key]: 0
# min[key]: 2
# key1 : blue
# j[key]: 11, min[key]: 0
# min[key]: 11
# newmin: {'red': 5, 'green': 2, 'blue': 11}
# Cycle end
# key1 : red
# j[key]: 10, min[key]: 5
# min[key]: 10
# key1 : blue
# j[key]: 15, min[key]: 11
# min[key]: 15
# newmin: {'red': 10, 'green': 2, 'blue': 15}
# Cycle end
# key1 : red
# j[key]: 19, min[key]: 10
# min[key]: 19
# key1 : green
# j[key]: 8, min[key]: 2
# min[key]: 8
# newmin: {'red': 19, 'green': 8, 'blue': 15}
# Cycle end
# key1 : red
# j[key]: 2, min[key]: 0
# min[key]: 2
# key1 : green
# j[key]: 7, min[key]: 0
# min[key]: 7
# key1 : blue
# j[key]: 1, min[key]: 0
# min[key]: 1
# newmin: {'red': 2, 'green': 7, 'blue': 1}
# Cycle end
# key1 : red
# j[key]: 5, min[key]: 2
# min[key]: 5
# key1 : green
# j[key]: 12, min[key]: 7
# min[key]: 12
# key1 : blue
# j[key]: 3, min[key]: 1
# min[key]: 3
# newmin: {'red': 5, 'green': 12, 'blue': 3}
# Cycle end
# key1 : blue
# j[key]: 4, min[key]: 3
# min[key]: 4
# newmin: {'red': 5, 'green': 12, 'blue': 4}
# Cycle end
# key1 : red
# j[key]: 9, min[key]: 0
# min[key]: 9
# key1 : green
# j[key]: 2, min[key]: 0
# min[key]: 2
# key1 : blue
# j[key]: 5, min[key]: 0
# min[key]: 5
# newmin: {'red': 9, 'green': 2, 'blue': 5}
# Cycle end
# key1 : green
# j[key]: 4, min[key]: 2
# min[key]: 4
# key1 : blue
# j[key]: 9, min[key]: 5
# min[key]: 9
# newmin: {'red': 9, 'green': 4, 'blue': 9}
# Cycle end
# key1 : green
# j[key]: 7, min[key]: 4
# min[key]: 7
# key1 : blue
# j[key]: 11, min[key]: 9
# min[key]: 11
# newmin: {'red': 9, 'green': 7, 'blue': 11}
# Cycle end
# key1 : red
# j[key]: 2, min[key]: 0
# min[key]: 2
# key1 : green
# j[key]: 2, min[key]: 0
# min[key]: 2
# key1 : blue
# j[key]: 15, min[key]: 0
# min[key]: 15
# newmin: {'red': 2, 'green': 2, 'blue': 15}
# Cycle end
# key1 : green
# j[key]: 6, min[key]: 2
# min[key]: 6
# newmin: {'red': 2, 'green': 6, 'blue': 15}
# Cycle end
# key1 : green
# j[key]: 11, min[key]: 6
# min[key]: 11
# key1 : blue
# j[key]: 18, min[key]: 15
# min[key]: 18
# newmin: {'red': 2, 'green': 11, 'blue': 18}
# Cycle end
# key1 : red
# j[key]: 3, min[key]: 2
# min[key]: 3
# newmin: {'red': 3, 'green': 11, 'blue': 18}
# Cycle end
# Ex
# Ex
# newmin: {'red': 3, 'green': 11, 'blue': 18}
# Cycle end
# key1 : red
# j[key]: 13, min[key]: 0
# min[key]: 13
# key1 : green
# j[key]: 2, min[key]: 0
# min[key]: 2
# Ex
# newmin: {'red': 13, 'green': 2, 'blue': 0}
# Cycle end
# key1 : red
# j[key]: 15, min[key]: 13
# min[key]: 15
# Ex
# newmin: {'red': 15, 'green': 2, 'blue': 0}
# Cycle end
# Ex
# key1 : green
# j[key]: 4, min[key]: 2
# min[key]: 4
# key1 : blue
# j[key]: 1, min[key]: 0
# min[key]: 1
# newmin: {'red': 15, 'green': 4, 'blue': 1}
# Cycle end
# key1 : green
# j[key]: 5, min[key]: 4
# min[key]: 5
# Ex
# newmin: {'red': 15, 'green': 5, 'blue': 1}
# Cycle end
# Ex
# newmin: {'red': 15, 'green': 5, 'blue': 1}
# Cycle end

# %%
print(min_set)
cubes = []
for i in min_set:
    temp = 1
    for j in i.values():
        #print(j)
        temp *= j
    print(temp)
    cubes.append(temp)
    print('stop')
print(sum(cubes))
# Out:
# [{'red': 7, 'green': 18, 'blue': 6}, {'red': 11, 'green': 12, 'blue': 1}, {'red': 16, 'green': 3, 'blue': 14}, {'red': 8, 'green': 4, 'blue': 9}, {'red': 4, 'green': 13, 'blue': 13}, {'red': 3, 'green': 6, 'blue': 13}, {'red': 2, 'green': 14, 'blue': 9}, {'red': 7, 'green': 11, 'blue': 7}, {'red': 7, 'green': 1, 'blue': 8}, {'red': 6, 'green': 6, 'blue': 7}, {'red': 8, 'green': 8, 'blue': 6}, {'red': 6, 'green': 10, 'blue': 7}, {'red': 11, 'green': 16, 'blue': 9}, {'red': 6, 'green': 12, 'blue': 11}, {'red': 8, 'green': 2, 'blue': 10}, {'red': 4, 'green': 7, 'blue': 16}, {'red': 2, 'green': 4, 'blue': 6}, {'red': 11, 'green': 12, 'blue': 9}, {'red': 18, 'green': 10, 'blue': 14}, {'red': 11, 'green': 15, 'blue': 3}, {'red': 6, 'green': 16, 'blue': 13}, {'red': 1, 'green': 1, 'blue': 16}, {'red': 10, 'green': 20, 'blue': 6}, {'red': 8, 'green': 11, 'blue': 13}, {'red': 9, 'green': 9, 'blue': 10}, {'red': 15, 'green': 5, 'blue': 9}, {'red': 9, 'green': 5, 'blue': 1}, {'red': 16, 'green': 19, 'blue': 8}, {'red': 17, 'green': 4, 'blue': 15}, {'red': 4, 'green': 2, 'blue': 2}, {'red': 8, 'green': 3, 'blue': 8}, {'red': 15, 'green': 12, 'blue': 4}, {'red': 5, 'green': 9, 'blue': 8}, {'red': 3, 'green': 12, 'blue': 12}, {'red': 4, 'green': 8, 'blue': 4}, {'red': 4, 'green': 9, 'blue': 18}, {'red': 10, 'green': 4, 'blue': 10}, {'red': 9, 'green': 6, 'blue': 6}, {'red': 9, 'green': 3, 'blue': 9}, {'red': 13, 'green': 8, 'blue': 2}, {'red': 10, 'green': 10, 'blue': 17}, {'red': 9, 'green': 2, 'blue': 9}, {'red': 16, 'green': 7, 'blue': 7}, {'red': 8, 'green': 1, 'blue': 9}, {'red': 17, 'green': 4, 'blue': 14}, {'red': 10, 'green': 7, 'blue': 4}, {'red': 16, 'green': 4, 'blue': 15}, {'red': 9, 'green': 10, 'blue': 1}, {'red': 18, 'green': 18, 'blue': 11}, {'red': 10, 'green': 7, 'blue': 6}, {'red': 14, 'green': 10, 'blue': 3}, {'red': 1, 'green': 8, 'blue': 7}, {'red': 16, 'green': 9, 'blue': 3}, {'red': 10, 'green': 1, 'blue': 6}, {'red': 18, 'green': 4, 'blue': 5}, {'red': 2, 'green': 14, 'blue': 18}, {'red': 12, 'green': 4, 'blue': 4}, {'red': 11, 'green': 17, 'blue': 2}, {'red': 1, 'green': 16, 'blue': 6}, {'red': 4, 'green': 17, 'blue': 11}, {'red': 12, 'green': 10, 'blue': 16}, {'red': 10, 'green': 1, 'blue': 15}, {'red': 2, 'green': 9, 'blue': 4}, {'red': 13, 'green': 10, 'blue': 2}, {'red': 7, 'green': 8, 'blue': 8}, {'red': 11, 'green': 17, 'blue': 3}, {'red': 2, 'green': 4, 'blue': 12}, {'red': 16, 'green': 16, 'blue': 16}, {'red': 14, 'green': 18, 'blue': 9}, {'red': 6, 'green': 3, 'blue': 12}, {'red': 6, 'green': 6, 'blue': 11}, {'red': 5, 'green': 11, 'blue': 9}, {'red': 13, 'green': 1, 'blue': 9}, {'red': 19, 'green': 7, 'blue': 3}, {'red': 4, 'green': 9, 'blue': 18}, {'red': 13, 'green': 14, 'blue': 10}, {'red': 3, 'green': 2, 'blue': 6}, {'red': 13, 'green': 15, 'blue': 9}, {'red': 6, 'green': 12, 'blue': 7}, {'red': 7, 'green': 18, 'blue': 5}, {'red': 10, 'green': 9, 'blue': 18}, {'red': 2, 'green': 14, 'blue': 2}, {'red': 12, 'green': 7, 'blue': 13}, {'red': 2, 'green': 10, 'blue': 5}, {'red': 13, 'green': 11, 'blue': 6}, {'red': 10, 'green': 2, 'blue': 2}, {'red': 13, 'green': 16, 'blue': 16}, {'red': 17, 'green': 15, 'blue': 4}, {'red': 13, 'green': 7, 'blue': 7}, {'red': 19, 'green': 7, 'blue': 19}, {'red': 14, 'green': 2, 'blue': 3}, {'red': 16, 'green': 3, 'blue': 15}, {'red': 3, 'green': 12, 'blue': 7}, {'red': 7, 'green': 12, 'blue': 10}, {'red': 16, 'green': 13, 'blue': 3}, {'red': 19, 'green': 8, 'blue': 15}, {'red': 5, 'green': 12, 'blue': 4}, {'red': 9, 'green': 7, 'blue': 11}, {'red': 3, 'green': 11, 'blue': 18}, {'red': 15, 'green': 5, 'blue': 1}]
# 756
# stop
# 132
# stop
# 672
# stop
# 288
# stop
# 676
# stop
# 234
# stop
# 252
# stop
# 539
# stop
# 56
# stop
# 252
# stop
# 384
# stop
# 420
# stop
# 1584
# stop
# 792
# stop
# 160
# stop
# 448
# stop
# 48
# stop
# 1188
# stop
# 2520
# stop
# 495
# stop
# 1248
# stop
# 16
# stop
# 1200
# stop
# 1144
# stop
# 810
# stop
# 675
# stop
# 45
# stop
# 2432
# stop
# 1020
# stop
# 16
# stop
# 192
# stop
# 720
# stop
# 360
# stop
# 432
# stop
# 128
# stop
# 648
# stop
# 400
# stop
# 324
# stop
# 243
# stop
# 208
# stop
# 1700
# stop
# 162
# stop
# 784
# stop
# 72
# stop
# 952
# stop
# 280
# stop
# 960
# stop
# 90
# stop
# 3564
# stop
# 420
# stop
# 420
# stop
# 56
# stop
# 432
# stop
# 60
# stop
# 360
# stop
# 504
# stop
# 192
# stop
# 374
# stop
# 96
# stop
# 748
# stop
# 1920
# stop
# 150
# stop
# 72
# stop
# 260
# stop
# 448
# stop
# 561
# stop
# 96
# stop
# 4096
# stop
# 2268
# stop
# 216
# stop
# 396
# stop
# 495
# stop
# 117
# stop
# 399
# stop
# 648
# stop
# 1820
# stop
# 36
# stop
# 1755
# stop
# 504
# stop
# 630
# stop
# 1620
# stop
# 56
# stop
# 1092
# stop
# 100
# stop
# 858
# stop
# 40
# stop
# 3328
# stop
# 1020
# stop
# 637
# stop
# 2527
# stop
# 84
# stop
# 720
# stop
# 252
# stop
# 840
# stop
# 624
# stop
# 2280
# stop
# 240
# stop
# 693
# stop
# 594
# stop
# 75
# stop
# 70950
